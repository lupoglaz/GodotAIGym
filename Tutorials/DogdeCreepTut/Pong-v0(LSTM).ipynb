# %%
import os
import random
import gym
import pylab
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Input, Dense, Lambda, Add, Conv2D, Flatten, LSTM, Reshape
from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras import backend as K
import cv2
import threading
from threading import Thread, Lock
import time
import tensorflow_probability as tfp
from typing import Any, List, Sequence, Tuple

gpus = tf.config.experimental.list_physical_devices('GPU')
tf.config.experimental.set_virtual_device_configuration(gpus[0],
            [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=6000)])

#os.environ['CUDA_VISIBLE_DEVICES'] = '-1'

tfd = tfp.distributions


class OurModel(tf.keras.Model):
    def __init__(self, input_shape, action_space):
        super(OurModel, self).__init__()
        
        self.flatten = Flatten()
        self.conv_1 = Conv2D(8, 8, 4, padding="valid", activation="relu")
        self.conv_2 = Conv2D(16, 4, 2, padding="valid", activation="relu")
        self.conv_3 = Conv2D(16, 3, 1, padding="valid", activation="relu")
        self.lstm = LSTM(64, return_sequences=True, return_state=True)
        self.dense_1 = Dense(action_space)
        self.dense_2 = Dense(1)
        self.dense_3 = Dense(256, activation='relu')
        
    def call(self, X_input, memory_state, carry_state):
        batch_size = X_input.shape[0]
        
        conv_1 = self.conv_1(X_input)
        conv_2 = self.conv_2(conv_1)
        conv_3 = self.conv_3(conv_2)
        X_input_reshaped = Reshape((36,16))(conv_3)
        
        initial_state = (memory_state, carry_state)
        LSTM_output, final_memory_state, final_carry_state = self.lstm(X_input_reshaped, 
                                                                       initial_state=initial_state)
        
        LSTM_output_flattened = Flatten()(LSTM_output)
        LSTM_output_flattened = self.dense_3(LSTM_output_flattened)
        
        action_logit = self.dense_1(LSTM_output_flattened)
        value = self.dense_2(LSTM_output_flattened)
        
        return action_logit, value, final_memory_state, final_carry_state


def safe_log(x):
  """Computes a safe logarithm which returns 0 if x is zero."""
  return tf.where(
      tf.math.equal(x, 0),
      tf.zeros_like(x),
      tf.math.log(tf.math.maximum(1e-12, x)))


def take_vector_elements(vectors, indices):
    """
    For a batch of vectors, take a single vector component
    out of each vector.
    Args:
      vectors: a [batch x dims] Tensor.
      indices: an int32 Tensor with `batch` entries.
    Returns:
      A Tensor with `batch` entries, one for each vector.
    """
    return tf.gather_nd(vectors, tf.stack([tf.range(tf.shape(vectors)[0]), indices], axis=1))


huber_loss = tf.keras.losses.Huber(reduction=tf.keras.losses.Reduction.SUM)
sparse_ce = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True, reduction=tf.keras.losses.Reduction.SUM)
mse_loss = tf.keras.losses.MeanSquaredError()


class A3CAgent:
    # Actor-Critic Main Optimization Algorithm
    def __init__(self, env_name):
        # Initialization
        # Environment and PPO parameters
        self.env_name = env_name       
        self.env = gym.make(env_name)
        self.action_size = self.env.action_space.n
        self.EPISODES, self.episode, self.max_average = 2000000, 0, -21.0 # specific for pong
        self.lock = Lock()
        self.lr = 0.000025

        self.ROWS = 80
        self.COLS = 80
        self.REM_STEP = 4

        # Instantiate plot memory
        self.scores, self.episodes, self.average = [], [], []

        self.Save_Path = 'Models'
        self.state_size = (self.REM_STEP, self.ROWS, self.COLS)
        
        if not os.path.exists(self.Save_Path): os.makedirs(self.Save_Path)
        self.path = '{}_A3C_{}'.format(self.env_name, self.lr)
        self.model_name = os.path.join(self.Save_Path, self.path)

        # Create Actor-Critic network model
        self.ActorCritic = OurModel(input_shape=self.state_size, action_space=self.action_size)
        
        self.learning_rate = 0.0001
        self.optimizer = tf.keras.optimizers.Adam(self.learning_rate)
    
    def act(self, state, memory_state, carry_state):
        memory_state = tf.constant(memory_state, tf.float32)
        carry_state = tf.constant(carry_state, tf.float32)
        
        # Use the network to predict the next action to take, using the model
        prediction = self.ActorCritic(state, memory_state, carry_state, training=False)
        action = tf.random.categorical(prediction[0], 1).numpy()

        memory_state = prediction[2].numpy()
        carry_state = prediction[3].numpy()
        
        return action[0][0], memory_state, carry_state

    def discount_rewards(self, reward):
        # Compute the gamma-discounted rewards over an episode
        gamma = 0.99    # discount rate
        running_add = 0
        discounted_r = np.zeros_like(reward)
        for i in reversed(range(0, len(reward))):
            if reward[i] != 0: # reset the sum, since this was a game boundary (pong specific!)
                running_add = 0

            running_add = running_add * gamma + reward[i]
            discounted_r[i] = running_add

        discounted_r -= np.mean(discounted_r) # normalizing the result
        discounted_r /= np.std(discounted_r) # divide by standard deviation

        return discounted_r
    
    def replay(self, states, actions, rewards, memory_states, carry_states):
        # reshape memory to appropriate shape for training
        states = np.vstack(states)
        
        memory_states = np.vstack(memory_states)
        carry_states = np.vstack(carry_states)
        
        batch_size = states.shape[0]
        
        # Compute discounted rewards
        discounted_r = self.discount_rewards(rewards)
        discounted_r_ = np.vstack(discounted_r)
        with tf.GradientTape() as tape:
            action_logits = tf.TensorArray(dtype=tf.float32, size=0, dynamic_size=True)
            values = tf.TensorArray(dtype=tf.float32, size=0, dynamic_size=True)
            
            memory_state = tf.expand_dims(memory_states[0], 0)
            carry_state = tf.expand_dims(carry_states[0], 0)
            for i in tf.range(0, batch_size):
                prediction = self.ActorCritic(tf.expand_dims(states[i], 0), 
                                              memory_state, carry_state, training=True)
                
                action_logits = action_logits.write(i, prediction[0][0])
                values = values.write(i, prediction[1][0])
                
                memory_state = prediction[2]
                carry_state = prediction[3]
                
            action_logits = action_logits.stack()
            values = values.stack()
            
            action_logits_selected = take_vector_elements(action_logits, actions)
            
            advantages = discounted_r - np.stack(values)[:, 0] 
            
            action_logits_selected = tf.nn.softmax(action_logits_selected)
            action_logits_selected_probs = tf.math.log(action_logits_selected)
            
            action_logits_ = tf.nn.softmax(action_logits)
            #action_logits_ = tf.math.log(action_logits_)
            dist = tfd.Categorical(probs=action_logits_)
            action_log_prob = dist.prob(actions)
            action_log_prob = tf.math.log(action_log_prob)
            #print("action_logits_selected_probs: ", action_logits_selected_probs)
            #print("action_log_prob.shape: ", action_log_prob)
            
            actor_loss = -tf.math.reduce_mean(action_log_prob * advantages) 
            #actor_loss = tf.cast(actor_loss, 'float32')
            
            action_probs = tf.nn.softmax(action_logits)
            #entropy_loss = tf.keras.losses.categorical_crossentropy(action_logits_probs, action_logits_probs)
            #actor_loss = sparse_ce(actions, action_probs, sample_weight=advantages)
            
            critic_loss_ = huber_loss(values, discounted_r)
            critic_loss = mse_loss(values, discounted_r_)
            critic_loss = tf.cast(critic_loss, 'float32')
            #print("critic_loss: ", critic_loss)
            total_loss = actor_loss + critic_loss
        
        #print("total_loss: ", total_loss)
        #print("")
            
        grads = tape.gradient(total_loss, self.ActorCritic.trainable_variables)
        self.optimizer.apply_gradients(zip(grads, self.ActorCritic.trainable_variables))
        
    def load(self, model_name):
        self.ActorCritic = load_model(model_name, compile=False)
        #self.Critic = load_model(Critic_name, compile=False)

    def save(self):
        self.ActorCritic.save(self.model_name)
        #self.Critic.save(self.Model_name + '_Critic.h5')

    pylab.figure(figsize=(18, 9))
    def PlotModel(self, score, episode):
        self.scores.append(score)
        self.episodes.append(episode)
        self.average.append(sum(self.scores[-50:]) / len(self.scores[-50:]))
        if str(episode)[-2:] == "00":# much faster than episode % 100
            pylab.plot(self.episodes, self.scores, 'b')
            pylab.plot(self.episodes, self.average, 'r')
            pylab.ylabel('Score', fontsize=18)
            pylab.xlabel('Steps', fontsize=18)
            try:
                pylab.savefig(self.path + ".png")
            except OSError:
                pass

        return self.average[-1]
    
    def reset(self, env):
        state = env.reset()
        state = state[35:195:2, ::2,:] / 255.0

        return state
    
    def step(self, action, env):
        next_state, reward, done, info = env.step(action)
        next_state = next_state[35:195:2, ::2,:] / 255.0
        
        return next_state, reward, done, info
    
    def train(self, n_threads):
        self.env.close()
        # Instantiate one environment per thread
        envs = [gym.make(self.env_name) for i in range(n_threads)]

        # Create threads
        threads = [threading.Thread(
                target=self.train_threading,
                daemon=True,
                args=(self, envs[i], i)) for i in range(n_threads)]

        for t in threads:
            time.sleep(2)
            t.start()
            
        for t in threads:
            time.sleep(10)
            t.join()
            
    def train_threading(self, agent, env, thread):
        while self.episode < self.EPISODES:
            # Reset episode
            score, done, SAVING = 0, False, ''
            state = self.reset(env)
            state = np.array([state])

            states, actions, rewards = [], [], []
            memory_states, carry_states = [], []
            
            memory_state = np.zeros([1,64], dtype=np.float32)
            carry_state = np.zeros([1,64], dtype=np.float32)
            while not done:
                action, memory_state, carry_state = agent.act(state, memory_state, carry_state)
                next_state, reward, done, _ = self.step(action, env)
                next_state = np.array([next_state])
                
                states.append(state)
                actions.append(action)
                rewards.append(reward)
                memory_states.append(memory_state)
                carry_states.append(carry_state)

                score += reward
                state = next_state
                    
            self.lock.acquire()
            self.replay(states, actions, rewards, memory_states, carry_states)
            self.lock.release()
            
            states, actions, rewards = [], [], []
                    
            # Update episode count
            with self.lock:
                average = self.PlotModel(score, self.episode)
                # saving best models
                if average >= self.max_average:
                    self.max_average = average
                    #self.save()
                    SAVING = "SAVING"
                else:
                    SAVING = ""

                print("episode: {}/{}, thread: {}, score: {}, average: {:.2f} {}".format(self.episode, self.EPISODES, thread, score, average, SAVING))
                if(self.episode < self.EPISODES):
                    self.episode += 1

        env.close()            

    def test(self, Actor_name, Critic_name):
        self.load(Actor_name, Critic_name)
        for e in range(100):
            state = self.reset(self.env)
            done = False
            score = 0
            while not done:
                self.env.render()
                action = np.argmax(self.Actor.predict(state))
                state, reward, done, _ = self.step(action, self.env, state)
                score += reward
                if done:
                    print("episode: {}/{}, score: {}".format(e, self.EPISODES, score))
                    break

        self.env.close()


if __name__ == "__main__":
    env_name = 'PongDeterministic-v4'
    #env_name = 'Pong-v0'
    agent = A3CAgent(env_name)
    
    #agent.run() # use as A2C
    agent.train(n_threads=1) # use as A3C
    #agent.test('Models/Pong-v0_A3C_2.5e-05_Actor.h5', '')
# Out:
# 2022-08-19 19:28:21.610508: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2022-08-19 19:28:22.902798: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-08-19 19:28:22.903566: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2022-08-19 19:28:22.926819: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-19 19:28:22.927161: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:09:00.0 name: NVIDIA GeForce RTX 3080 computeCapability: 8.6
# coreClock: 1.71GHz coreCount: 68 deviceMemorySize: 9.78GiB deviceMemoryBandwidth: 707.88GiB/s
# 2022-08-19 19:28:22.927175: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2022-08-19 19:28:22.929986: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2022-08-19 19:28:22.930016: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2022-08-19 19:28:22.931403: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2022-08-19 19:28:22.931565: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2022-08-19 19:28:22.933227: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2022-08-19 19:28:22.933756: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2022-08-19 19:28:22.933833: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2022-08-19 19:28:22.933923: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-19 19:28:22.934310: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-19 19:28:22.934613: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2022-08-19 19:28:23.050170: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-08-19 19:28:23.050691: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-08-19 19:28:23.050864: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-19 19:28:23.051237: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:09:00.0 name: NVIDIA GeForce RTX 3080 computeCapability: 8.6
# coreClock: 1.71GHz coreCount: 68 deviceMemorySize: 9.78GiB deviceMemoryBandwidth: 707.88GiB/s
# 2022-08-19 19:28:23.051275: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2022-08-19 19:28:23.051295: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2022-08-19 19:28:23.051304: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2022-08-19 19:28:23.051311: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2022-08-19 19:28:23.051318: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2022-08-19 19:28:23.051325: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2022-08-19 19:28:23.051332: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2022-08-19 19:28:23.051338: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2022-08-19 19:28:23.051394: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-19 19:28:23.051740: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-19 19:28:23.052034: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2022-08-19 19:28:23.052059: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2022-08-19 19:28:23.415883: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-08-19 19:28:23.415907: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0
# 2022-08-19 19:28:23.415912: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N
# 2022-08-19 19:28:23.416076: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-19 19:28:23.416437: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-19 19:28:23.416745: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-19 19:28:23.417049: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 6000 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce RTX 3080, pci bus id: 0000:09:00.0, compute capability: 8.6)
# 2022-08-19 19:28:25.629256: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2022-08-19 19:28:27.902413: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:27.902541: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] Unimplemented: /usr/local/cuda-11.0/bin/ptxas ptxas too old. Falling back to the driver to compile.
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 2022-08-19 19:28:28.024511: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:28.145580: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:28.263942: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
# 2022-08-19 19:28:28.383131: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:28.506625: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:28.623654: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:28.740881: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:28.861002: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:28.983360: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:29.108666: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:29.226407: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:29.227390: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2022-08-19 19:28:29.786171: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2022-08-19 19:28:29.951443: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:30.094009: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:30.231256: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:30.395706: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:30.691926: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:31.050363: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:31.204157: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:31.344274: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:31.487473: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:31.624932: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:31.766594: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:31.918556: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:32.065101: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:32.205157: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:32.345375: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:32.490571: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:32.633049: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:32.776134: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:32.916732: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
# 2022-08-19 19:28:33.059749: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:33.197955: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:33.336547: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:33.483716: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:33.624006: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:33.763895: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:33.906515: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:34.047681: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:34.186789: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:34.325120: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:34.468454: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:34.607370: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:34.747572: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:34.892675: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:35.031277: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:35.170816: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:35.312187: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:35.454187: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:35.591726: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:35.729252: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:35.876331: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:36.014158: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:36.153847: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:36.293911: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:36.437938: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:36.449091: I tensorflow/stream_executor/cuda/cuda_blas.cc:1838] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2022-08-19 19:28:44.713714: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:44.871600: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
# 2022-08-19 19:28:45.022412: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:45.176222: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:45.329273: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:45.479639: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:45.631362: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:45.784913: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:45.936993: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:46.093125: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:46.248226: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:46.402771: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:46.551138: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:46.704807: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:46.858682: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:47.013262: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:47.169425: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:47.331133: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:47.486713: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:47.636424: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:47.793850: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:47.949052: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:48.101124: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:48.254805: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:48.408435: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:48.559563: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:48.714457: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:48.864185: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:49.015885: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:49.168367: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
# 2022-08-19 19:28:49.321450: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:49.470218: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:49.622306: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:49.777211: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:49.927675: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:50.076286: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:50.231299: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:50.381274: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:50.533025: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:50.688433: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:50.858673: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:51.013366: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:51.173480: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:51.323378: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:51.491180: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:51.652990: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:51.811597: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:51.976321: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:52.134099: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:52.285865: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:52.439618: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:52.591630: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:52.746019: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:52.898147: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:53.050786: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:53.206058: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:53.356924: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:53.507478: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
# 2022-08-19 19:28:53.663204: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:53.814499: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:53.966712: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:54.121556: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:54.277062: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:54.426481: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:54.587200: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:54.740622: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:54.897311: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:55.055052: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:55.217235: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:55.375473: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:55.533421: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2022-08-19 19:28:55.692447: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# ...
# episode: 3364/2000000, thread: 0, score: -21.0, average: -20.20
# episode: 3365/2000000, thread: 0, score: -21.0, average: -20.20
# episode: 3366/2000000, thread: 0, score: -21.0, average: -20.20
# episode: 3367/2000000, thread: 0, score: -21.0, average: -20.22
# episode: 3368/2000000, thread: 0, score: -21.0, average: -20.24
# episode: 3369/2000000, thread: 0, score: -20.0, average: -20.24
# episode: 3370/2000000, thread: 0, score: -21.0, average: -20.24
# episode: 3371/2000000, thread: 0, score: -20.0, average: -20.22
# episode: 3372/2000000, thread: 0, score: -20.0, average: -20.22
# episode: 3373/2000000, thread: 0, score: -20.0, average: -20.22
# episode: 3374/2000000, thread: 0, score: -20.0, average: -20.24
# episode: 3375/2000000, thread: 0, score: -20.0, average: -20.22
# episode: 3376/2000000, thread: 0, score: -21.0, average: -20.26
# episode: 3377/2000000, thread: 0, score: -21.0, average: -20.28
# episode: 3378/2000000, thread: 0, score: -18.0, average: -20.22
# episode: 3379/2000000, thread: 0, score: -21.0, average: -20.22
# episode: 3380/2000000, thread: 0, score: -20.0, average: -20.20
# episode: 3381/2000000, thread: 0, score: -18.0, average: -20.18
# episode: 3382/2000000, thread: 0, score: -21.0, average: -20.20
# episode: 3383/2000000, thread: 0, score: -20.0, average: -20.18
# episode: 3384/2000000, thread: 0, score: -20.0, average: -20.16
# episode: 3385/2000000, thread: 0, score: -20.0, average: -20.16
# episode: 3386/2000000, thread: 0, score: -21.0, average: -20.18
# episode: 3387/2000000, thread: 0, score: -20.0, average: -20.20
# episode: 3388/2000000, thread: 0, score: -21.0, average: -20.22
# episode: 3389/2000000, thread: 0, score: -20.0, average: -20.22
# episode: 3390/2000000, thread: 0, score: -21.0, average: -20.22
# episode: 3391/2000000, thread: 0, score: -19.0, average: -20.20
# episode: 3392/2000000, thread: 0, score: -20.0, average: -20.18
# episode: 3393/2000000, thread: 0, score: -21.0, average: -20.20
# episode: 3394/2000000, thread: 0, score: -20.0, average: -20.20
# episode: 3395/2000000, thread: 0, score: -20.0, average: -20.20
# episode: 3396/2000000, thread: 0, score: -20.0, average: -20.22
# episode: 3397/2000000, thread: 0, score: -19.0, average: -20.22
# episode: 3398/2000000, thread: 0, score: -20.0, average: -20.22
# episode: 3399/2000000, thread: 0, score: -20.0, average: -20.20
# episode: 3400/2000000, thread: 0, score: -19.0, average: -20.20
# episode: 3401/2000000, thread: 0, score: -21.0, average: -20.22
# episode: 3402/2000000, thread: 0, score: -20.0, average: -20.22
# episode: 3403/2000000, thread: 0, score: -21.0, average: -20.26
# episode: 3404/2000000, thread: 0, score: -21.0, average: -20.26
# episode: 3405/2000000, thread: 0, score: -21.0, average: -20.26
# episode: 3406/2000000, thread: 0, score: -21.0, average: -20.28
# episode: 3407/2000000, thread: 0, score: -20.0, average: -20.26
# episode: 3408/2000000, thread: 0, score: -20.0, average: -20.26
# episode: 3409/2000000, thread: 0, score: -19.0, average: -20.24
# episode: 3410/2000000, thread: 0, score: -20.0, average: -20.24
# episode: 3411/2000000, thread: 0, score: -18.0, average: -20.20
# episode: 3412/2000000, thread: 0, score: -21.0, average: -20.22
# episode: 3413/2000000, thread: 0, score: -20.0, average: -20.20
# episode: 3414/2000000, thread: 0, score: -19.0, average: -20.16
# episode: 3415/2000000, thread: 0, score: -21.0, average: -20.16
# episode: 3416/2000000, thread: 0, score: -20.0, average: -20.14
# episode: 3417/2000000, thread: 0, score: -21.0, average: -20.14
# episode: 3418/2000000, thread: 0, score: -19.0, average: -20.10
# episode: 3419/2000000, thread: 0, score: -20.0, average: -20.10
# episode: 3420/2000000, thread: 0, score: -20.0, average: -20.08
# episode: 3421/2000000, thread: 0, score: -20.0, average: -20.08
# episode: 3422/2000000, thread: 0, score: -20.0, average: -20.08
# episode: 3423/2000000, thread: 0, score: -19.0, average: -20.06
# episode: 3424/2000000, thread: 0, score: -21.0, average: -20.08
# episode: 3425/2000000, thread: 0, score: -21.0, average: -20.10
# episode: 3426/2000000, thread: 0, score: -18.0, average: -20.04
# episode: 3427/2000000, thread: 0, score: -19.0, average: -20.00
# episode: 3428/2000000, thread: 0, score: -20.0, average: -20.04
# episode: 3429/2000000, thread: 0, score: -19.0, average: -20.00
# episode: 3430/2000000, thread: 0, score: -20.0, average: -20.00
# episode: 3431/2000000, thread: 0, score: -18.0, average: -20.00
# episode: 3432/2000000, thread: 0, score: -20.0, average: -19.98
# episode: 3433/2000000, thread: 0, score: -21.0, average: -20.00
# episode: 3434/2000000, thread: 0, score: -19.0, average: -19.98
# episode: 3435/2000000, thread: 0, score: -21.0, average: -20.00
# episode: 3436/2000000, thread: 0, score: -21.0, average: -20.00
# episode: 3437/2000000, thread: 0, score: -21.0, average: -20.02
# episode: 3438/2000000, thread: 0, score: -20.0, average: -20.00
# episode: 3439/2000000, thread: 0, score: -20.0, average: -20.00
# episode: 3440/2000000, thread: 0, score: -20.0, average: -19.98
# episode: 3441/2000000, thread: 0, score: -21.0, average: -20.02
# episode: 3442/2000000, thread: 0, score: -21.0, average: -20.04
# episode: 3443/2000000, thread: 0, score: -21.0, average: -20.04
# episode: 3444/2000000, thread: 0, score: -19.0, average: -20.02
# episode: 3445/2000000, thread: 0, score: -19.0, average: -20.00
# episode: 3446/2000000, thread: 0, score: -20.0, average: -20.00
# episode: 3447/2000000, thread: 0, score: -21.0, average: -20.04
# episode: 3448/2000000, thread: 0, score: -21.0, average: -20.06
# episode: 3449/2000000, thread: 0, score: -18.0, average: -20.02
# episode: 3450/2000000, thread: 0, score: -21.0, average: -20.06
# episode: 3451/2000000, thread: 0, score: -20.0, average: -20.04
# episode: 3452/2000000, thread: 0, score: -20.0, average: -20.04
# episode: 3453/2000000, thread: 0, score: -20.0, average: -20.02
# episode: 3454/2000000, thread: 0, score: -20.0, average: -20.00
# episode: 3455/2000000, thread: 0, score: -20.0, average: -19.98
# episode: 3456/2000000, thread: 0, score: -21.0, average: -19.98
# episode: 3457/2000000, thread: 0, score: -20.0, average: -19.98
# episode: 3458/2000000, thread: 0, score: -21.0, average: -20.00
# episode: 3459/2000000, thread: 0, score: -21.0, average: -20.04
# episode: 3460/2000000, thread: 0, score: -21.0, average: -20.06
# episode: 3461/2000000, thread: 0, score: -20.0, average: -20.10
# episode: 3462/2000000, thread: 0, score: -21.0, average: -20.10
# episode: 3463/2000000, thread: 0, score: -21.0, average: -20.12
# episode: 3464/2000000, thread: 0, score: -21.0, average: -20.16
# episode: 3465/2000000, thread: 0, score: -21.0, average: -20.16
# episode: 3466/2000000, thread: 0, score: -21.0, average: -20.18
# episode: 3467/2000000, thread: 0, score: -19.0, average: -20.14
# episode: 3468/2000000, thread: 0, score: -21.0, average: -20.18
# episode: 3469/2000000, thread: 0, score: -20.0, average: -20.18
# episode: 3470/2000000, thread: 0, score: -19.0, average: -20.16
# episode: 3471/2000000, thread: 0, score: -21.0, average: -20.18
# episode: 3472/2000000, thread: 0, score: -21.0, average: -20.20
# episode: 3473/2000000, thread: 0, score: -20.0, average: -20.22
# episode: 3474/2000000, thread: 0, score: -21.0, average: -20.22
# episode: 3475/2000000, thread: 0, score: -20.0, average: -20.20
# episode: 3476/2000000, thread: 0, score: -19.0, average: -20.22
# episode: 3477/2000000, thread: 0, score: -18.0, average: -20.20
# episode: 3478/2000000, thread: 0, score: -19.0, average: -20.18
# episode: 3479/2000000, thread: 0, score: -18.0, average: -20.16
# episode: 3480/2000000, thread: 0, score: -19.0, average: -20.14
# episode: 3481/2000000, thread: 0, score: -21.0, average: -20.20
# episode: 3482/2000000, thread: 0, score: -21.0, average: -20.22
# episode: 3483/2000000, thread: 0, score: -19.0, average: -20.18
# episode: 3484/2000000, thread: 0, score: -20.0, average: -20.20
# episode: 3485/2000000, thread: 0, score: -20.0, average: -20.18
# episode: 3486/2000000, thread: 0, score: -21.0, average: -20.18
# episode: 3487/2000000, thread: 0, score: -20.0, average: -20.16
# episode: 3488/2000000, thread: 0, score: -20.0, average: -20.16
# episode: 3489/2000000, thread: 0, score: -19.0, average: -20.14
# episode: 3490/2000000, thread: 0, score: -20.0, average: -20.14
# episode: 3491/2000000, thread: 0, score: -20.0, average: -20.12
# episode: 3492/2000000, thread: 0, score: -21.0, average: -20.12
# episode: 3493/2000000, thread: 0, score: -20.0, average: -20.10
# episode: 3494/2000000, thread: 0, score: -19.0, average: -20.10
# episode: 3495/2000000, thread: 0, score: -21.0, average: -20.14
# episode: 3496/2000000, thread: 0, score: -20.0, average: -20.14
# episode: 3497/2000000, thread: 0, score: -20.0, average: -20.12
# episode: 3498/2000000, thread: 0, score: -21.0, average: -20.12
# episode: 3499/2000000, thread: 0, score: -21.0, average: -20.18
# episode: 3500/2000000, thread: 0, score: -20.0, average: -20.16
# episode: 3501/2000000, thread: 0, score: -16.0, average: -20.08
# episode: 3502/2000000, thread: 0, score: -21.0, average: -20.10
# episode: 3503/2000000, thread: 0, score: -21.0, average: -20.12
# episode: 3504/2000000, thread: 0, score: -20.0, average: -20.12
# episode: 3505/2000000, thread: 0, score: -21.0, average: -20.14
# episode: 3506/2000000, thread: 0, score: -21.0, average: -20.14
# episode: 3507/2000000, thread: 0, score: -20.0, average: -20.14
# episode: 3508/2000000, thread: 0, score: -21.0, average: -20.14
# episode: 3509/2000000, thread: 0, score: -21.0, average: -20.14
# episode: 3510/2000000, thread: 0, score: -21.0, average: -20.14
# episode: 3511/2000000, thread: 0, score: -20.0, average: -20.14
# episode: 3512/2000000, thread: 0, score: -21.0, average: -20.14
# episode: 3513/2000000, thread: 0, score: -21.0, average: -20.14
# episode: 3514/2000000, thread: 0, score: -18.0, average: -20.08
# episode: 3515/2000000, thread: 0, score: -21.0, average: -20.08
# episode: 3516/2000000, thread: 0, score: -21.0, average: -20.08
# episode: 3517/2000000, thread: 0, score: -21.0, average: -20.12
# episode: 3518/2000000, thread: 0, score: -19.0, average: -20.08
# episode: 3519/2000000, thread: 0, score: -21.0, average: -20.10
# episode: 3520/2000000, thread: 0, score: -20.0, average: -20.12
# episode: 3521/2000000, thread: 0, score: -20.0, average: -20.10
# episode: 3522/2000000, thread: 0, score: -21.0, average: -20.10
# episode: 3523/2000000, thread: 0, score: -20.0, average: -20.10
# episode: 3524/2000000, thread: 0, score: -18.0, average: -20.04
# episode: 3525/2000000, thread: 0, score: -21.0, average: -20.06
# episode: 3526/2000000, thread: 0, score: -21.0, average: -20.10
# episode: 3527/2000000, thread: 0, score: -21.0, average: -20.16
# episode: 3528/2000000, thread: 0, score: -21.0, average: -20.20
# episode: 3529/2000000, thread: 0, score: -19.0, average: -20.22
# episode: 3530/2000000, thread: 0, score: -20.0, average: -20.24
# episode: 3531/2000000, thread: 0, score: -19.0, average: -20.20
# episode: 3532/2000000, thread: 0, score: -21.0, average: -20.20
# episode: 3533/2000000, thread: 0, score: -20.0, average: -20.22
# episode: 3534/2000000, thread: 0, score: -21.0, average: -20.24
# episode: 3535/2000000, thread: 0, score: -21.0, average: -20.26
# episode: 3536/2000000, thread: 0, score: -20.0, average: -20.24
# episode: 3537/2000000, thread: 0, score: -21.0, average: -20.26
# episode: 3538/2000000, thread: 0, score: -20.0, average: -20.26
# episode: 3539/2000000, thread: 0, score: -20.0, average: -20.28
# episode: 3540/2000000, thread: 0, score: -21.0, average: -20.30
# episode: 3541/2000000, thread: 0, score: -19.0, average: -20.28
# episode: 3542/2000000, thread: 0, score: -20.0, average: -20.26
# episode: 3543/2000000, thread: 0, score: -20.0, average: -20.26
# episode: 3544/2000000, thread: 0, score: -20.0, average: -20.28
# episode: 3545/2000000, thread: 0, score: -20.0, average: -20.26
# episode: 3546/2000000, thread: 0, score: -19.0, average: -20.24
# episode: 3547/2000000, thread: 0, score: -21.0, average: -20.26
# episode: 3548/2000000, thread: 0, score: -21.0, average: -20.26
# episode: 3549/2000000, thread: 0, score: -21.0, average: -20.26
# episode: 3550/2000000, thread: 0, score: -21.0, average: -20.28
# episode: 3551/2000000, thread: 0, score: -19.0, average: -20.34
# episode: 3552/2000000, thread: 0, score: -20.0, average: -20.32
# episode: 3553/2000000, thread: 0, score: -21.0, average: -20.32
# episode: 3554/2000000, thread: 0, score: -20.0, average: -20.32
# episode: 3555/2000000, thread: 0, score: -21.0, average: -20.32
# episode: 3556/2000000, thread: 0, score: -21.0, average: -20.32
# episode: 3557/2000000, thread: 0, score: -18.0, average: -20.28
# episode: 3558/2000000, thread: 0, score: -18.0, average: -20.22
# episode: 3559/2000000, thread: 0, score: -20.0, average: -20.20
# episode: 3560/2000000, thread: 0, score: -21.0, average: -20.20
# episode: 3561/2000000, thread: 0, score: -20.0, average: -20.20
# episode: 3562/2000000, thread: 0, score: -19.0, average: -20.16
# episode: 3563/2000000, thread: 0, score: -20.0, average: -20.14
# episode: 3564/2000000, thread: 0, score: -21.0, average: -20.20
# episode: 3565/2000000, thread: 0, score: -20.0, average: -20.18
# episode: 3566/2000000, thread: 0, score: -20.0, average: -20.16
# episode: 3567/2000000, thread: 0, score: -19.0, average: -20.12
# episode: 3568/2000000, thread: 0, score: -20.0, average: -20.14
# episode: 3569/2000000, thread: 0, score: -20.0, average: -20.12
# episode: 3570/2000000, thread: 0, score: -19.0, average: -20.10
# episode: 3571/2000000, thread: 0, score: -21.0, average: -20.12
# episode: 3572/2000000, thread: 0, score: -21.0, average: -20.12
# episode: 3573/2000000, thread: 0, score: -21.0, average: -20.14
# episode: 3574/2000000, thread: 0, score: -20.0, average: -20.18
# episode: 3575/2000000, thread: 0, score: -21.0, average: -20.18
# episode: 3576/2000000, thread: 0, score: -21.0, average: -20.18
# episode: 3577/2000000, thread: 0, score: -21.0, average: -20.18
# episode: 3578/2000000, thread: 0, score: -21.0, average: -20.18
# episode: 3579/2000000, thread: 0, score: -19.0, average: -20.18
# episode: 3580/2000000, thread: 0, score: -19.0, average: -20.16
# episode: 3581/2000000, thread: 0, score: -19.0, average: -20.16
# episode: 3582/2000000, thread: 0, score: -21.0, average: -20.16
# episode: 3583/2000000, thread: 0, score: -21.0, average: -20.18
# episode: 3584/2000000, thread: 0, score: -21.0, average: -20.18
# episode: 3585/2000000, thread: 0, score: -21.0, average: -20.18
# episode: 3586/2000000, thread: 0, score: -21.0, average: -20.20
# episode: 3587/2000000, thread: 0, score: -21.0, average: -20.20
# episode: 3588/2000000, thread: 0, score: -20.0, average: -20.20
# episode: 3589/2000000, thread: 0, score: -21.0, average: -20.22
# episode: 3590/2000000, thread: 0, score: -20.0, average: -20.20
# episode: 3591/2000000, thread: 0, score: -21.0, average: -20.24
# episode: 3592/2000000, thread: 0, score: -20.0, average: -20.24
# episode: 3593/2000000, thread: 0, score: -21.0, average: -20.26
# episode: 3594/2000000, thread: 0, score: -21.0, average: -20.28
# episode: 3595/2000000, thread: 0, score: -21.0, average: -20.30
# episode: 3596/2000000, thread: 0, score: -21.0, average: -20.34
# episode: 3597/2000000, thread: 0, score: -21.0, average: -20.34
# episode: 3598/2000000, thread: 0, score: -21.0, average: -20.34
# episode: 3599/2000000, thread: 0, score: -18.0, average: -20.28
# episode: 3600/2000000, thread: 0, score: -21.0, average: -20.28
# episode: 3601/2000000, thread: 0, score: -21.0, average: -20.32
# episode: 3602/2000000, thread: 0, score: -21.0, average: -20.34
# episode: 3603/2000000, thread: 0, score: -20.0, average: -20.32
# episode: 3604/2000000, thread: 0, score: -19.0, average: -20.30
# episode: 3605/2000000, thread: 0, score: -20.0, average: -20.28
# episode: 3606/2000000, thread: 0, score: -21.0, average: -20.28
# episode: 3607/2000000, thread: 0, score: -20.0, average: -20.32
# episode: 3608/2000000, thread: 0, score: -21.0, average: -20.38
# episode: 3609/2000000, thread: 0, score: -21.0, average: -20.40
