# %%
import os
import random
import gym
import pylab
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Input, Dense, Lambda, Add, Conv2D, Flatten
from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras import backend as K
import cv2
import threading
from threading import Thread, Lock
import time
import tensorflow_probability as tfp
from typing import Any, List, Sequence, Tuple
from dodgeCreep import dodgeCreepEnv

os.environ['CUDA_VISIBLE_DEVICES'] = '-1'

'''
gpus = tf.config.experimental.list_physical_devices('GPU')
tf.config.experimental.set_virtual_device_configuration(gpus[0],
            [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=4000)])
'''
tfd = tfp.distributions


def scaled_dot_product_attention(q, k, v, mask):
  matmul_qk = tf.matmul(q, k, transpose_b=True)  # (..., seq_len_q, seq_len_k)

  # scale matmul_qk
  dk = tf.cast(tf.shape(k)[-1], tf.float32)
  scaled_attention_logits = matmul_qk / tf.math.sqrt(dk)

  # add the mask to the scaled tensor.
  if mask is not None:
    scaled_attention_logits += (mask * -1e9)

  # softmax is normalized on the last axis (seq_len_k) so that the scores
  # add up to 1.
  attention_weights = tf.nn.softmax(scaled_attention_logits, axis=-1)  # (..., seq_len_q, seq_len_k)

  output = tf.matmul(attention_weights, v)  # (..., seq_len_q, depth_v)

  return output, attention_weights
  
    
class MultiHeadAttention(tf.keras.layers.Layer):
  def __init__(self, d_model, num_heads):
    super(MultiHeadAttention, self).__init__()
    self.num_heads = num_heads
    self.d_model = d_model

    assert d_model % self.num_heads == 0

    self.depth = d_model // self.num_heads

    self.wq = tf.keras.layers.Dense(d_model)
    self.wk = tf.keras.layers.Dense(d_model)
    self.wv = tf.keras.layers.Dense(d_model)

    self.dense = tf.keras.layers.Dense(d_model)

  def split_heads(self, x, batch_size):
    """Split the last dimension into (num_heads, depth).
    Transpose the result such that the shape is (batch_size, num_heads, seq_len, depth)
    """
    x = tf.reshape(x, (batch_size, -1, self.num_heads, self.depth))
    return tf.transpose(x, perm=[0, 2, 1, 3])

  def call(self, v, k, q, mask):
    batch_size = tf.shape(q)[0]

    q = self.wq(q)  # (batch_size, seq_len, d_model)
    k = self.wk(k)  # (batch_size, seq_len, d_model)
    v = self.wv(v)  # (batch_size, seq_len, d_model)

    q = self.split_heads(q, batch_size)  # (batch_size, num_heads, seq_len_q, depth)
    k = self.split_heads(k, batch_size)  # (batch_size, num_heads, seq_len_k, depth)
    v = self.split_heads(v, batch_size)  # (batch_size, num_heads, seq_len_v, depth)

    # scaled_attention.shape == (batch_size, num_heads, seq_len_q, depth)
    # attention_weights.shape == (batch_size, num_heads, seq_len_q, seq_len_k)
    scaled_attention, attention_weights = scaled_dot_product_attention(
        q, k, v, mask)

    scaled_attention = tf.transpose(scaled_attention, perm=[0, 2, 1, 3])  # (batch_size, seq_len_q, num_heads, depth)

    concat_attention = tf.reshape(scaled_attention,
                                  (batch_size, -1, self.d_model))  # (batch_size, seq_len_q, d_model)

    output = self.dense(concat_attention)  # (batch_size, seq_len_q, d_model)

    return output, attention_weights


class OurModel(tf.keras.Model):
    def __init__(self, input_shape, action_space):
        super(OurModel, self).__init__()
        
        self.flatten = Flatten()
        
        #self.dense_a = Dense(1024, activation='relu')
        #self.dense_b = Dense(1024, activation='relu')
        #self.dense_c = Dense(1024, activation='relu')
        self.conv_1 = Conv2D(32, 3, 2, padding="valid", activation="relu")
        self.conv_2 = Conv2D(64, 3, 2, padding="valid", activation="relu")
        self.conv_3 = Conv2D(63, 3, 2, padding="valid", activation="relu")
        
        self.attention_1 = MultiHeadAttention(64, 4)
        self.layernorm_1 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
        self.dropout_1 = tf.keras.layers.Dropout(0.1)
        
        self._conv_out_size = 9
        self._locs = []
        for i in range(0, self._conv_out_size*self._conv_out_size):
            self._locs.append(i / float(self._conv_out_size*self._conv_out_size))

        self._locs = tf.expand_dims(self._locs, 0)
        self._locs = tf.expand_dims(self._locs, 2)
        
        self.dense_1 = Dense(action_space)
        self.dense_2 = Dense(1)
        
    def call(self, X_input, training):
        batch_size = tf.shape(X_input)[0]
        
        #print("X_input.shape: ", X_input.shape)
        #X_input = self.flatten(X_input)
        #dense_a = self.dense_a(X_input)
        #dense_b = self.dense_b(dense_a)
        #dense_c = self.dense_c(dense_b)
        X_input = tf.transpose(X_input, perm=[0, 2, 3, 1])
        
        conv_1 = self.conv_1(X_input)
        conv_2 = self.conv_2(conv_1)
        conv_3 = self.conv_3(conv_2)
        #print("conv_3.shape: ", conv_3.shape)
        
        conv_3_features = tf.reshape(conv_3, [batch_size,self._conv_out_size*self._conv_out_size,63])
        
        locs = tf.tile(self._locs, [batch_size, 1, 1])
        conv_3_features_locs = tf.concat([conv_3_features, locs], 2)

        attention_output_1, _ = self.attention_1(conv_3_features_locs, conv_3_features_locs, conv_3_features_locs, None)
        attention_output_1 = self.dropout_1(attention_output_1, training=training)
        attention_output_1 = self.layernorm_1(conv_3_features_locs + attention_output_1)

        attention_max_pool_1d = tf.math.reduce_max(attention_output_1, 1)
        
        attention_flattened = Flatten()(attention_max_pool_1d)
        
        action_logit = self.dense_1(attention_flattened)
        value = self.dense_2(attention_flattened)
        
        return action_logit, value


def safe_log(x):
  """Computes a safe logarithm which returns 0 if x is zero."""
  return tf.where(
      tf.math.equal(x, 0),
      tf.zeros_like(x),
      tf.math.log(tf.math.maximum(1e-12, x)))


def take_vector_elements(vectors, indices):
    """
    For a batch of vectors, take a single vector component
    out of each vector.
    Args:
      vectors: a [batch x dims] Tensor.
      indices: an int32 Tensor with `batch` entries.
    Returns:
      A Tensor with `batch` entries, one for each vector.
    """
    return tf.gather_nd(vectors, tf.stack([tf.range(tf.shape(vectors)[0]), indices], axis=1))


huber_loss = tf.keras.losses.Huber(reduction=tf.keras.losses.Reduction.SUM)
sparse_ce = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True, reduction=tf.keras.losses.Reduction.SUM)
mse_loss = tf.keras.losses.MeanSquaredError()


class A3CAgent:
    # Actor-Critic Main Optimization Algorithm
    def __init__(self, env_name):
        # Initialization
        self.env_name = env_name       
        GODOT_BIN_PATH = "dodge_the_creeps/DodgeCreep.x86_64"
        env_abs_path = "dodge_the_creeps/DodgeCreep.pck"
        self.env = dodgeCreepEnv(exec_path=GODOT_BIN_PATH, env_path=env_abs_path, turbo_mode=True)
        
        self.action_size = 5
        self.EPISODES, self.episode, self.max_average = 2000000, 0, 50.0 # specific for pong
        self.lock = Lock()
        self.lr = 0.00001

        self.ROWS = 80
        self.COLS = 80
        self.REM_STEP = 4

        # Instantiate plot memory
        self.scores, self.episodes, self.average = [], [], []

        self.Save_Path = 'Models'
        self.state_size = (self.REM_STEP, self.ROWS, self.COLS)
        
        if not os.path.exists(self.Save_Path): os.makedirs(self.Save_Path)
        self.path = '{}_A3C_{}'.format(self.env_name, self.lr)
        self.model_name = os.path.join(self.Save_Path, self.path)

        # Create Actor-Critic network model
        self.ActorCritic = OurModel(input_shape=self.state_size, action_space=self.action_size)
        
        self.optimizer = tf.keras.optimizers.Adam(self.lr)

    def act(self, state):
        # Use the network to predict the next action to take, using the model
        prediction = self.ActorCritic(state, training=False)
        action = tf.random.categorical(prediction[0], 1).numpy()

        return action[0][0]

    def discount_rewards(self, reward, dones):
        # Compute the gamma-discounted rewards over an episode
        gamma = 0.99    # discount rate
        running_add = 0
        discounted_r = np.zeros_like(reward)
        for i in reversed(range(0, len(reward))):
            if reward[i] != 0: # reset the sum, since this was a game boundary (pong specific!)
                running_add = 0

            running_add = running_add * gamma + reward[i]
            discounted_r[i] = running_add

        discounted_r -= np.mean(discounted_r) # normalizing the result
        discounted_r /= np.std(discounted_r) # divide by standard deviation

        return discounted_r
        
    def replay(self, states, actions, rewards, dones):
        # reshape memory to appropriate shape for training
        states = np.vstack(states)
        
        # Compute discounted rewards
        discounted_r = self.discount_rewards(rewards, dones)
        discounted_r_ = np.vstack(discounted_r)
        with tf.GradientTape() as tape:
            prediction = self.ActorCritic(states, training=True)
            action_logits = prediction[0]
            values = prediction[1]
            
            action_logits_selected = take_vector_elements(action_logits, actions)
            
            advantages = discounted_r - np.stack(values)[:, 0] 
            
            action_logits_selected = tf.nn.softmax(action_logits_selected)
            action_logits_selected_probs = tf.math.log(action_logits_selected)
            
            action_logits_ = tf.nn.softmax(action_logits)
            dist = tfd.Categorical(probs=action_logits_)
            action_log_prob = dist.prob(actions)
            action_log_prob = tf.math.log(action_log_prob)
            
            actor_loss = -tf.math.reduce_mean(action_logits_selected_probs * advantages) 
            
            action_probs = tf.nn.softmax(action_logits)
            
            critic_loss = huber_loss(values, discounted_r)
            #critic_loss = mse_loss(values, discounted_r_)
            critic_loss = tf.cast(critic_loss, 'float32')
            #print("critic_loss: ", critic_loss)
            
            entropy_loss = -tf.math.reduce_mean(action_logits_selected * tf.math.log(action_logits_selected))
            
            total_loss = actor_loss + 0.5 * critic_loss - 0.01 * entropy_loss
        
        #print("total_loss: ", total_loss)
        #print("")
            
        grads = tape.gradient(total_loss, self.ActorCritic.trainable_variables)
        self.optimizer.apply_gradients(zip(grads, self.ActorCritic.trainable_variables))
        
    def load(self, model_name):
        self.ActorCritic = load_model(model_name, compile=False)
        #self.Critic = load_model(Critic_name, compile=False)

    def save(self):
        self.ActorCritic.save(self.model_name)
        #self.Critic.save(self.Model_name + '_Critic.h5')

    pylab.figure(figsize=(18, 9))
    def PlotModel(self, score, episode):
        self.scores.append(score)
        self.episodes.append(episode)
        self.average.append(sum(self.scores[-50:]) / len(self.scores[-50:]))
        if str(episode)[-2:] == "00":# much faster than episode % 100
            pylab.plot(self.episodes, self.scores, 'b')
            pylab.plot(self.episodes, self.average, 'r')
            pylab.ylabel('Score', fontsize=18)
            pylab.xlabel('Steps', fontsize=18)
            try:
                pylab.savefig(self.path + ".png")
            except OSError:
                pass

        return self.average[-1]
    
    def imshow(self, image, rem_step=0):
        cv2.imshow(self.model_name + str(rem_step), image[rem_step,...])
        if cv2.waitKey(25) & 0xFF == ord("q"):
            cv2.destroyAllWindows()
            return

    def GetImage(self, frame, image_memory):
        if image_memory.shape == (1,*self.state_size):
            image_memory = np.squeeze(image_memory)
        
        # croping frame to 80x80 size
        frame_cropped = frame[35:195:2, ::2,:]
        if frame_cropped.shape[0] != self.COLS or frame_cropped.shape[1] != self.ROWS:
            # OpenCV resize function 
            frame_cropped = cv2.resize(frame, (self.COLS, self.ROWS), interpolation=cv2.INTER_CUBIC)
        
        # converting to RGB (numpy way)
        frame_rgb = 0.299*frame_cropped[:,:,0] + 0.587*frame_cropped[:,:,1] + 0.114*frame_cropped[:,:,2]

        # convert everything to black and white (agent will train faster)
        frame_rgb[frame_rgb < 70] = 0
        frame_rgb[frame_rgb >= 100] = 255
        
        #cv2.imshow("frame_rgb: ", frame_rgb)
        #if cv2.waitKey(25) & 0xFF == ord("q"):
        #    cv2.destroyAllWindows()
        
        # dividing by 255 we expresses value to 0-1 representation
        new_frame = np.array(frame_rgb).astype(np.float32) / 255.0

        # push our data by 1 frame, similar as deq() function work
        image_memory = np.roll(image_memory, 1, axis = 0)

        # inserting new frame to free space
        image_memory[0,:,:] = new_frame

        return np.expand_dims(image_memory, axis=0)

    def reset(self, env):
        image_memory = np.zeros(self.state_size)
        frame = env.reset()
        frame = np.reshape(frame, (128,128,3))
        frame = frame.astype(np.uint8)
        
        for i in range(self.REM_STEP):
            state = self.GetImage(frame, image_memory)
            
        return state
    
    def step(self, action, env, image_memory):
        next_frame, reward, done, info = env.step(action)
        next_frame = np.reshape(next_frame, (128,128,3))
        next_frame = next_frame.astype(np.uint8)
        
        next_state = self.GetImage(next_frame, image_memory)
        
        return next_state, reward, done, info
    
    def train(self, n_threads):
        self.env.close()
        # Instantiate one environment per thread
        GODOT_BIN_PATH = "dodge_the_creeps/DodgeCreep.x86_64"
        env_abs_path = "dodge_the_creeps/DodgeCreep.pck"
        envs = [dodgeCreepEnv(exec_path=GODOT_BIN_PATH, env_path=env_abs_path, turbo_mode=True) 
                for i in range(n_threads)]

        # Create threads
        threads = [threading.Thread(target=self.train_threading, daemon=True, 
                                    args=(self, envs[i], i)) for i in range(n_threads)]

        for t in threads:
            time.sleep(1)
            t.start()
            
        for t in threads:
            time.sleep(1)
            t.join()
            
    def train_threading(self, agent, env, thread):
        while self.episode < self.EPISODES:
            # Reset episode
            score, done, SAVING = 0, False, ''
            
            state = self.reset(env)

            states, actions, rewards, dones = [], [], [], []
            while not done:
                action = agent.act(state)
                next_state, reward, done, _ = self.step(action, env, state)
                
                #print("action: ", action)
                #print("next_state.shape: ", next_state.shape)
                
                reward = reward[0]
                done = done[0]
                
                #print("reward: ", reward)
                #print("done: ", done)
                #next_state = np.expand_dims(next_state, axis=0)
                    
                states.append(state)
                actions.append(action)
                rewards.append(reward)
                dones.append(done)

                score += reward
                state = next_state
            
            self.lock.acquire()
            self.replay(states, actions, rewards, dones)
            self.lock.release()
            
            states, actions, rewards, dones = [], [], [], []
                    
            # Update episode count
            with self.lock:
                average = self.PlotModel(score, self.episode)
                # saving best models
                if average >= self.max_average:
                    self.max_average = average
                    #self.save()
                    SAVING = "SAVING"
                else:
                    SAVING = ""

                print("episode: {}/{}, thread: {}, score: {}, average: {:.2f} {}".format(self.episode, self.EPISODES, thread, score, average, SAVING))
                if(self.episode < self.EPISODES):
                    self.episode += 1

        env.close()            

    def test(self, Actor_name, Critic_name):
        self.load(Actor_name, Critic_name)
        for e in range(100):
            state = self.reset(self.env)
            done = False
            score = 0
            while not done:
                self.env.render()
                action = np.argmax(self.Actor.predict(state))
                state, reward, done, _ = self.step(action, self.env, state)
                score += reward
                if done:
                    print("episode: {}/{}, score: {}".format(e, self.EPISODES, score))
                    break

        self.env.close()


if __name__ == "__main__":
    env_name = 'DodgeCreep'
    agent = A3CAgent(env_name)
    
    #agent.run() # use as A2C
    agent.train(n_threads=1) # use as A3C
    #agent.test('Models/Pong-v0_A3C_2.5e-05_Actor.h5', '')
# Out:
# 2022-08-15 19:38:57.253590: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# _GodotEnv.__file__:  /usr/local/lib/python3.7/dist-packages/GodotEnv-0.1-py3.7-linux-x86_64.egg/_GodotEnv.cpython-37m-x86_64-linux-gnu.so
# Created float32 vector agent_action size = 1
# Created int32 vector env_action size = 1
# Created uint32 vector observation size = 49152
# Created float32 vector reward size = 1
# Created int32 vector done size = 1
# Terminated
# Created float32 vector agent_action size = 1
# Created int32 vector env_action size = 1
# Created uint32 vector observation size = 49152
# Created float32 vector reward size = 1
# Created int32 vector done size = 1
# 2022-08-15 19:38:58.834732: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-08-15 19:38:58.835443: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2022-08-15 19:38:58.839344: E tensorflow/stream_executor/cuda/cuda_driver.cc:328] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-08-15 19:38:58.839366: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: kimbring2-ROG-Strix-GA35DX-G35DX
# 2022-08-15 19:38:58.839370: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: kimbring2-ROG-Strix-GA35DX-G35DX
# 2022-08-15 19:38:58.839461: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 470.42.1
# 2022-08-15 19:38:58.839477: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 470.42.1
# 2022-08-15 19:38:58.839481: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:310] kernel version seems to match DSO: 470.42.1
# 2022-08-15 19:38:58.839688: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-08-15 19:38:58.840182: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# episode: 0/2000000, thread: 0, score: -1.0, average: -1.00
# episode: 1/2000000, thread: 0, score: -1.0, average: -1.00
# episode: 2/2000000, thread: 0, score: -1.0, average: -1.00
# episode: 3/2000000, thread: 0, score: -1.0, average: -1.00
# episode: 4/2000000, thread: 0, score: 0.0, average: -0.80
# episode: 5/2000000, thread: 0, score: -1.0, average: -0.83
# episode: 6/2000000, thread: 0, score: -1.0, average: -0.86
# episode: 7/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 8/2000000, thread: 0, score: -1.0, average: -0.89
# episode: 9/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 10/2000000, thread: 0, score: -1.0, average: -0.91
# episode: 11/2000000, thread: 0, score: 0.0, average: -0.83
# episode: 12/2000000, thread: 0, score: -1.0, average: -0.85
# episode: 13/2000000, thread: 0, score: -1.0, average: -0.86
# episode: 14/2000000, thread: 0, score: -1.0, average: -0.87
# episode: 15/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 16/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 17/2000000, thread: 0, score: -1.0, average: -0.89
# episode: 18/2000000, thread: 0, score: -1.0, average: -0.89
# episode: 19/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 20/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 21/2000000, thread: 0, score: -1.0, average: -0.91
# episode: 22/2000000, thread: 0, score: -1.0, average: -0.91
# episode: 23/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 24/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 25/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 26/2000000, thread: 0, score: -1.0, average: -0.93
# episode: 27/2000000, thread: 0, score: -1.0, average: -0.93
# episode: 28/2000000, thread: 0, score: 0.0, average: -0.90
# episode: 29/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 30/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 31/2000000, thread: 0, score: -1.0, average: -0.91
# episode: 32/2000000, thread: 0, score: -1.0, average: -0.91
# episode: 33/2000000, thread: 0, score: -1.0, average: -0.91
# episode: 34/2000000, thread: 0, score: -1.0, average: -0.91
# episode: 35/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 36/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 37/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 38/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 39/2000000, thread: 0, score: -1.0, average: -0.93
# episode: 40/2000000, thread: 0, score: -1.0, average: -0.93
# episode: 41/2000000, thread: 0, score: -1.0, average: -0.93
# episode: 42/2000000, thread: 0, score: -1.0, average: -0.93
# episode: 43/2000000, thread: 0, score: -1.0, average: -0.93
# episode: 44/2000000, thread: 0, score: -1.0, average: -0.93
# episode: 45/2000000, thread: 0, score: 0.0, average: -0.91
# episode: 46/2000000, thread: 0, score: -1.0, average: -0.91
# episode: 47/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 48/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 49/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 50/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 51/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 52/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 53/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 54/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 55/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 56/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 57/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 58/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 59/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 60/2000000, thread: 0, score: 0.0, average: -0.92
# episode: 61/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 62/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 63/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 64/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 65/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 66/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 67/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 68/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 69/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 70/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 71/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 72/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 73/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 74/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 75/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 76/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 77/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 78/2000000, thread: 0, score: -1.0, average: -0.96
# episode: 79/2000000, thread: 0, score: -1.0, average: -0.96
# episode: 80/2000000, thread: 0, score: -1.0, average: -0.96
# episode: 81/2000000, thread: 0, score: -1.0, average: -0.96
# episode: 82/2000000, thread: 0, score: -1.0, average: -0.96
# episode: 83/2000000, thread: 0, score: -1.0, average: -0.96
# episode: 84/2000000, thread: 0, score: -1.0, average: -0.96
# episode: 85/2000000, thread: 0, score: -1.0, average: -0.96
# episode: 86/2000000, thread: 0, score: -1.0, average: -0.96
# episode: 87/2000000, thread: 0, score: -1.0, average: -0.96
# episode: 88/2000000, thread: 0, score: -1.0, average: -0.96
# episode: 89/2000000, thread: 0, score: -1.0, average: -0.96
# episode: 90/2000000, thread: 0, score: -1.0, average: -0.96
# episode: 91/2000000, thread: 0, score: -1.0, average: -0.96
# episode: 92/2000000, thread: 0, score: -1.0, average: -0.96
# episode: 93/2000000, thread: 0, score: 0.0, average: -0.94
# episode: 94/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 95/2000000, thread: 0, score: -1.0, average: -0.96
# episode: 96/2000000, thread: 0, score: -1.0, average: -0.96
# episode: 97/2000000, thread: 0, score: -1.0, average: -0.96
# episode: 98/2000000, thread: 0, score: -1.0, average: -0.96
# episode: 99/2000000, thread: 0, score: -1.0, average: -0.96
# episode: 100/2000000, thread: 0, score: 0.0, average: -0.94
# episode: 101/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 102/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 103/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 104/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 105/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 106/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 107/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 108/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 109/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 110/2000000, thread: 0, score: 0.0, average: -0.94
# episode: 111/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 112/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 113/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 114/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 115/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 116/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 117/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 118/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 119/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 120/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 121/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 122/2000000, thread: 0, score: 0.0, average: -0.92
# episode: 123/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 124/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 125/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 126/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 127/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 128/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 129/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 130/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 131/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 132/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 133/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 134/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 135/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 136/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 137/2000000, thread: 0, score: 0.0, average: -0.90
# episode: 138/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 139/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 140/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 141/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 142/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 143/2000000, thread: 0, score: 0.0, average: -0.90
# episode: 144/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 145/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 146/2000000, thread: 0, score: 0.0, average: -0.88
# episode: 147/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 148/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 149/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 150/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 151/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 152/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 153/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 154/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 155/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 156/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 157/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 158/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 159/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 160/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 161/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 162/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 163/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 164/2000000, thread: 0, score: 0.0, average: -0.90
# episode: 165/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 166/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 167/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 168/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 169/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 170/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 171/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 172/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 173/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 174/2000000, thread: 0, score: 0.0, average: -0.90
# episode: 175/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 176/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 177/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 178/2000000, thread: 0, score: 0.0, average: -0.88
# episode: 179/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 180/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 181/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 182/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 183/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 184/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 185/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 186/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 187/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 188/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 189/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 190/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 191/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 192/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 193/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 194/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 195/2000000, thread: 0, score: 0.0, average: -0.90
# episode: 196/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 197/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 198/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 199/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 200/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 201/2000000, thread: 0, score: 0.0, average: -0.90
# episode: 202/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 203/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 204/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 205/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 206/2000000, thread: 0, score: 0.0, average: -0.88
# episode: 207/2000000, thread: 0, score: 0.0, average: -0.86
# episode: 208/2000000, thread: 0, score: -1.0, average: -0.86
# episode: 209/2000000, thread: 0, score: -1.0, average: -0.86
# episode: 210/2000000, thread: 0, score: -1.0, average: -0.86
# episode: 211/2000000, thread: 0, score: -1.0, average: -0.86
# episode: 212/2000000, thread: 0, score: -1.0, average: -0.86
# episode: 213/2000000, thread: 0, score: -1.0, average: -0.86
# episode: 214/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 215/2000000, thread: 0, score: 0.0, average: -0.86
# episode: 216/2000000, thread: 0, score: -1.0, average: -0.86
# episode: 217/2000000, thread: 0, score: 0.0, average: -0.84
# episode: 218/2000000, thread: 0, score: -1.0, average: -0.84
# episode: 219/2000000, thread: 0, score: -1.0, average: -0.84
# episode: 220/2000000, thread: 0, score: -1.0, average: -0.84
# episode: 221/2000000, thread: 0, score: -1.0, average: -0.84
# episode: 222/2000000, thread: 0, score: -1.0, average: -0.84
# episode: 223/2000000, thread: 0, score: -1.0, average: -0.84
# episode: 224/2000000, thread: 0, score: -1.0, average: -0.86
# episode: 225/2000000, thread: 0, score: -1.0, average: -0.86
# episode: 226/2000000, thread: 0, score: -1.0, average: -0.86
# episode: 227/2000000, thread: 0, score: -1.0, average: -0.86
# episode: 228/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 229/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 230/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 231/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 232/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 233/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 234/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 235/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 236/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 237/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 238/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 239/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 240/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 241/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 242/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 243/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 244/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 245/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 246/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 247/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 248/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 249/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 250/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 251/2000000, thread: 0, score: 0.0, average: -0.90
# episode: 252/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 253/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 254/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 255/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 256/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 257/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 258/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 259/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 260/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 261/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 262/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 263/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 264/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 265/2000000, thread: 0, score: -1.0, average: -0.96
# episode: 266/2000000, thread: 0, score: -1.0, average: -0.96
# episode: 267/2000000, thread: 0, score: -1.0, average: -0.98
# episode: 268/2000000, thread: 0, score: 0.0, average: -0.96
# episode: 269/2000000, thread: 0, score: 0.0, average: -0.94
# episode: 270/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 271/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 272/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 273/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 274/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 275/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 276/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 277/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 278/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 279/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 280/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 281/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 282/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 283/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 284/2000000, thread: 0, score: 0.0, average: -0.92
# episode: 285/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 286/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 287/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 288/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 289/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 290/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 291/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 292/2000000, thread: 0, score: 1.0, average: -0.88
# episode: 293/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 294/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 295/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 296/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 297/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 298/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 299/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 300/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 301/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 302/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 303/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 304/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 305/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 306/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 307/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 308/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 309/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 310/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 311/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 312/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 313/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 314/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 315/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 316/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 317/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 318/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 319/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 320/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 321/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 322/2000000, thread: 0, score: 0.0, average: -0.92
# episode: 323/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 324/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 325/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 326/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 327/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 328/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 329/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 330/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 331/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 332/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 333/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 334/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 335/2000000, thread: 0, score: 0.0, average: -0.92
# episode: 336/2000000, thread: 0, score: 0.0, average: -0.90
# episode: 337/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 338/2000000, thread: 0, score: 0.0, average: -0.88
# episode: 339/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 340/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 341/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 342/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 343/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 344/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 345/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 346/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 347/2000000, thread: 0, score: 0.0, average: -0.90
# episode: 348/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 349/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 350/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 351/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 352/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 353/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 354/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 355/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 356/2000000, thread: 0, score: 2.0, average: -0.84
# episode: 357/2000000, thread: 0, score: -1.0, average: -0.84
# episode: 358/2000000, thread: 0, score: -1.0, average: -0.84
# episode: 359/2000000, thread: 0, score: -1.0, average: -0.84
# episode: 360/2000000, thread: 0, score: -1.0, average: -0.84
# episode: 361/2000000, thread: 0, score: -1.0, average: -0.84
# episode: 362/2000000, thread: 0, score: -1.0, average: -0.84
# episode: 363/2000000, thread: 0, score: -1.0, average: -0.84
# episode: 364/2000000, thread: 0, score: -1.0, average: -0.84
# episode: 365/2000000, thread: 0, score: -1.0, average: -0.84
# episode: 366/2000000, thread: 0, score: -1.0, average: -0.84
# episode: 367/2000000, thread: 0, score: -1.0, average: -0.84
# episode: 368/2000000, thread: 0, score: -1.0, average: -0.84
# episode: 369/2000000, thread: 0, score: -1.0, average: -0.84
# episode: 370/2000000, thread: 0, score: -1.0, average: -0.84
# episode: 371/2000000, thread: 0, score: -1.0, average: -0.84
# episode: 372/2000000, thread: 0, score: 0.0, average: -0.84
# episode: 373/2000000, thread: 0, score: -1.0, average: -0.84
# episode: 374/2000000, thread: 0, score: -1.0, average: -0.84
# episode: 375/2000000, thread: 0, score: -1.0, average: -0.84
# episode: 376/2000000, thread: 0, score: 0.0, average: -0.82
# episode: 377/2000000, thread: 0, score: -1.0, average: -0.82
# episode: 378/2000000, thread: 0, score: -1.0, average: -0.82
# episode: 379/2000000, thread: 0, score: -1.0, average: -0.82
# episode: 380/2000000, thread: 0, score: -1.0, average: -0.82
# episode: 381/2000000, thread: 0, score: -1.0, average: -0.82
# episode: 382/2000000, thread: 0, score: -1.0, average: -0.82
# episode: 383/2000000, thread: 0, score: -1.0, average: -0.82
# episode: 384/2000000, thread: 0, score: -1.0, average: -0.82
# episode: 385/2000000, thread: 0, score: -1.0, average: -0.84
# episode: 386/2000000, thread: 0, score: -1.0, average: -0.86
# episode: 387/2000000, thread: 0, score: -1.0, average: -0.86
# episode: 388/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 389/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 390/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 391/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 392/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 393/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 394/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 395/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 396/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 397/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 398/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 399/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 400/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 401/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 402/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 403/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 404/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 405/2000000, thread: 0, score: 0.0, average: -0.88
# episode: 406/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 407/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 408/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 409/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 410/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 411/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 412/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 413/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 414/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 415/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 416/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 417/2000000, thread: 0, score: 0.0, average: -0.92
# episode: 418/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 419/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 420/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 421/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 422/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 423/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 424/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 425/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 426/2000000, thread: 0, score: -1.0, average: -0.96
# episode: 427/2000000, thread: 0, score: -1.0, average: -0.96
# episode: 428/2000000, thread: 0, score: -1.0, average: -0.96
# episode: 429/2000000, thread: 0, score: -1.0, average: -0.96
# episode: 430/2000000, thread: 0, score: -1.0, average: -0.96
# episode: 431/2000000, thread: 0, score: -1.0, average: -0.96
# episode: 432/2000000, thread: 0, score: -1.0, average: -0.96
# episode: 433/2000000, thread: 0, score: -1.0, average: -0.96
# episode: 434/2000000, thread: 0, score: -1.0, average: -0.96
# episode: 435/2000000, thread: 0, score: -1.0, average: -0.96
# episode: 436/2000000, thread: 0, score: -1.0, average: -0.96
# episode: 437/2000000, thread: 0, score: -1.0, average: -0.96
# episode: 438/2000000, thread: 0, score: -1.0, average: -0.96
# episode: 439/2000000, thread: 0, score: -1.0, average: -0.96
# episode: 440/2000000, thread: 0, score: 0.0, average: -0.94
# episode: 441/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 442/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 443/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 444/2000000, thread: 0, score: 0.0, average: -0.92
# episode: 445/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 446/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 447/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 448/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 449/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 450/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 451/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 452/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 453/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 454/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 455/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 456/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 457/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 458/2000000, thread: 0, score: 0.0, average: -0.92
# episode: 459/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 460/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 461/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 462/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 463/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 464/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 465/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 466/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 467/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 468/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 469/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 470/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 471/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 472/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 473/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 474/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 475/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 476/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 477/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 478/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 479/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 480/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 481/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 482/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 483/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 484/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 485/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 486/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 487/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 488/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 489/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 490/2000000, thread: 0, score: -1.0, average: -0.96
# episode: 491/2000000, thread: 0, score: -1.0, average: -0.96
# episode: 492/2000000, thread: 0, score: -1.0, average: -0.96
# episode: 493/2000000, thread: 0, score: 0.0, average: -0.94
# episode: 494/2000000, thread: 0, score: -1.0, average: -0.96
# episode: 495/2000000, thread: 0, score: -1.0, average: -0.96
# episode: 496/2000000, thread: 0, score: -1.0, average: -0.96
# episode: 497/2000000, thread: 0, score: -1.0, average: -0.96
# episode: 498/2000000, thread: 0, score: -1.0, average: -0.96
# episode: 499/2000000, thread: 0, score: -1.0, average: -0.96
# episode: 500/2000000, thread: 0, score: -1.0, average: -0.96
# episode: 501/2000000, thread: 0, score: -1.0, average: -0.96
# episode: 502/2000000, thread: 0, score: -1.0, average: -0.96
# episode: 503/2000000, thread: 0, score: -1.0, average: -0.96
# episode: 504/2000000, thread: 0, score: -1.0, average: -0.96
# episode: 505/2000000, thread: 0, score: -1.0, average: -0.96
# episode: 506/2000000, thread: 0, score: -1.0, average: -0.96
# episode: 507/2000000, thread: 0, score: -1.0, average: -0.96
# episode: 508/2000000, thread: 0, score: -1.0, average: -0.98
# episode: 509/2000000, thread: 0, score: -1.0, average: -0.98
# episode: 510/2000000, thread: 0, score: -1.0, average: -0.98
# episode: 511/2000000, thread: 0, score: -1.0, average: -0.98
# episode: 512/2000000, thread: 0, score: -1.0, average: -0.98
# episode: 513/2000000, thread: 0, score: -1.0, average: -0.98
# episode: 514/2000000, thread: 0, score: -1.0, average: -0.98
# episode: 515/2000000, thread: 0, score: -1.0, average: -0.98
# episode: 516/2000000, thread: 0, score: -1.0, average: -0.98
# episode: 517/2000000, thread: 0, score: -1.0, average: -0.98
# episode: 518/2000000, thread: 0, score: -1.0, average: -0.98
# episode: 519/2000000, thread: 0, score: -1.0, average: -0.98
# episode: 520/2000000, thread: 0, score: -1.0, average: -0.98
# episode: 521/2000000, thread: 0, score: -1.0, average: -0.98
# episode: 522/2000000, thread: 0, score: -1.0, average: -0.98
# episode: 523/2000000, thread: 0, score: -1.0, average: -0.98
# episode: 524/2000000, thread: 0, score: -1.0, average: -0.98
# episode: 525/2000000, thread: 0, score: -1.0, average: -0.98
# episode: 526/2000000, thread: 0, score: -1.0, average: -0.98
# episode: 527/2000000, thread: 0, score: -1.0, average: -0.98
# episode: 528/2000000, thread: 0, score: 0.0, average: -0.96
# episode: 529/2000000, thread: 0, score: -1.0, average: -0.96
# episode: 530/2000000, thread: 0, score: -1.0, average: -0.96
# episode: 531/2000000, thread: 0, score: -1.0, average: -0.96
# episode: 532/2000000, thread: 0, score: -1.0, average: -0.96
# episode: 533/2000000, thread: 0, score: -1.0, average: -0.96
# episode: 534/2000000, thread: 0, score: -1.0, average: -0.96
# episode: 535/2000000, thread: 0, score: -1.0, average: -0.96
# episode: 536/2000000, thread: 0, score: -1.0, average: -0.96
# episode: 537/2000000, thread: 0, score: -1.0, average: -0.96
# episode: 538/2000000, thread: 0, score: -1.0, average: -0.96
# episode: 539/2000000, thread: 0, score: -1.0, average: -0.96
# episode: 540/2000000, thread: 0, score: -1.0, average: -0.96
# episode: 541/2000000, thread: 0, score: 0.0, average: -0.94
# episode: 542/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 543/2000000, thread: 0, score: 0.0, average: -0.94
# episode: 544/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 545/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 546/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 547/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 548/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 549/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 550/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 551/2000000, thread: 0, score: 0.0, average: -0.92
# episode: 552/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 553/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 554/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 555/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 556/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 557/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 558/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 559/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 560/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 561/2000000, thread: 0, score: 0.0, average: -0.90
# episode: 562/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 563/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 564/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 565/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 566/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 567/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 568/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 569/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 570/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 571/2000000, thread: 0, score: 0.0, average: -0.88
# episode: 572/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 573/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 574/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 575/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 576/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 577/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 578/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 579/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 580/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 581/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 582/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 583/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 584/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 585/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 586/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 587/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 588/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 589/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 590/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 591/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 592/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 593/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 594/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 595/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 596/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 597/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 598/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 599/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 600/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 601/2000000, thread: 0, score: -1.0, average: -0.96
# episode: 602/2000000, thread: 0, score: -1.0, average: -0.96
# episode: 603/2000000, thread: 0, score: -1.0, average: -0.96
# episode: 604/2000000, thread: 0, score: -1.0, average: -0.96
# episode: 605/2000000, thread: 0, score: -1.0, average: -0.96
# episode: 606/2000000, thread: 0, score: -1.0, average: -0.96
# episode: 607/2000000, thread: 0, score: -1.0, average: -0.96
# episode: 608/2000000, thread: 0, score: -1.0, average: -0.96
# episode: 609/2000000, thread: 0, score: -1.0, average: -0.96
# episode: 610/2000000, thread: 0, score: -1.0, average: -0.96
# episode: 611/2000000, thread: 0, score: -1.0, average: -0.98
# episode: 612/2000000, thread: 0, score: -1.0, average: -0.98
# episode: 613/2000000, thread: 0, score: 0.0, average: -0.96
# episode: 614/2000000, thread: 0, score: -1.0, average: -0.96
# episode: 615/2000000, thread: 0, score: -1.0, average: -0.96
# episode: 616/2000000, thread: 0, score: -1.0, average: -0.96
# episode: 617/2000000, thread: 0, score: -1.0, average: -0.96
# episode: 618/2000000, thread: 0, score: -1.0, average: -0.96
# episode: 619/2000000, thread: 0, score: -1.0, average: -0.96
# episode: 620/2000000, thread: 0, score: -1.0, average: -0.96
# episode: 621/2000000, thread: 0, score: -1.0, average: -0.98
# episode: 622/2000000, thread: 0, score: -1.0, average: -0.98
# episode: 623/2000000, thread: 0, score: -1.0, average: -0.98
# episode: 624/2000000, thread: 0, score: -1.0, average: -0.98
# episode: 625/2000000, thread: 0, score: -1.0, average: -0.98
# episode: 626/2000000, thread: 0, score: -1.0, average: -0.98
# episode: 627/2000000, thread: 0, score: -1.0, average: -0.98
# episode: 628/2000000, thread: 0, score: -1.0, average: -0.98
# episode: 629/2000000, thread: 0, score: -1.0, average: -0.98
# episode: 630/2000000, thread: 0, score: -1.0, average: -0.98
# episode: 631/2000000, thread: 0, score: -1.0, average: -0.98
# episode: 632/2000000, thread: 0, score: -1.0, average: -0.98
# episode: 633/2000000, thread: 0, score: -1.0, average: -0.98
# episode: 634/2000000, thread: 0, score: -1.0, average: -0.98
# episode: 635/2000000, thread: 0, score: -1.0, average: -0.98
# episode: 636/2000000, thread: 0, score: -1.0, average: -0.98
# episode: 637/2000000, thread: 0, score: -1.0, average: -0.98
# episode: 638/2000000, thread: 0, score: -1.0, average: -0.98
# episode: 639/2000000, thread: 0, score: -1.0, average: -0.98
# episode: 640/2000000, thread: 0, score: -1.0, average: -0.98
# episode: 641/2000000, thread: 0, score: -1.0, average: -0.98
# episode: 642/2000000, thread: 0, score: -1.0, average: -0.98
# episode: 643/2000000, thread: 0, score: -1.0, average: -0.98
# episode: 644/2000000, thread: 0, score: -1.0, average: -0.98
# episode: 645/2000000, thread: 0, score: -1.0, average: -0.98
# episode: 646/2000000, thread: 0, score: 0.0, average: -0.96
# episode: 647/2000000, thread: 0, score: -1.0, average: -0.96
# episode: 648/2000000, thread: 0, score: 0.0, average: -0.94
# episode: 649/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 650/2000000, thread: 0, score: 0.0, average: -0.92
# episode: 651/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 652/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 653/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 654/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 655/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 656/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 657/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 658/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 659/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 660/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 661/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 662/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 663/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 664/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 665/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 666/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 667/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 668/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 669/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 670/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 671/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 672/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 673/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 674/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 675/2000000, thread: 0, score: 0.0, average: -0.92
# episode: 676/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 677/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 678/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 679/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 680/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 681/2000000, thread: 0, score: 0.0, average: -0.90
# episode: 682/2000000, thread: 0, score: 0.0, average: -0.88
# episode: 683/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 684/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 685/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 686/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 687/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 688/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 689/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 690/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 691/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 692/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 693/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 694/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 695/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 696/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 697/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 698/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 699/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 700/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 701/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 702/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 703/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 704/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 705/2000000, thread: 0, score: 0.0, average: -0.92
# episode: 706/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 707/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 708/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 709/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 710/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 711/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 712/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 713/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 714/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 715/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 716/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 717/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 718/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 719/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 720/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 721/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 722/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 723/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 724/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 725/2000000, thread: 0, score: 0.0, average: -0.92
# episode: 726/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 727/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 728/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 729/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 730/2000000, thread: 0, score: 0.0, average: -0.90
# episode: 731/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 732/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 733/2000000, thread: 0, score: -1.0, average: -0.94
# episode: 734/2000000, thread: 0, score: 1.0, average: -0.90
# episode: 735/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 736/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 737/2000000, thread: 0, score: 1.0, average: -0.86
# episode: 738/2000000, thread: 0, score: -1.0, average: -0.86
# episode: 739/2000000, thread: 0, score: -1.0, average: -0.86
# episode: 740/2000000, thread: 0, score: -1.0, average: -0.86
# episode: 741/2000000, thread: 0, score: -1.0, average: -0.86
# episode: 742/2000000, thread: 0, score: -1.0, average: -0.86
# episode: 743/2000000, thread: 0, score: -1.0, average: -0.86
# episode: 744/2000000, thread: 0, score: -1.0, average: -0.86
# episode: 745/2000000, thread: 0, score: -1.0, average: -0.86
# episode: 746/2000000, thread: 0, score: -1.0, average: -0.86
# episode: 747/2000000, thread: 0, score: -1.0, average: -0.86
# episode: 748/2000000, thread: 0, score: -1.0, average: -0.86
# episode: 749/2000000, thread: 0, score: -1.0, average: -0.86
# episode: 750/2000000, thread: 0, score: -1.0, average: -0.86
# episode: 751/2000000, thread: 0, score: -1.0, average: -0.86
# episode: 752/2000000, thread: 0, score: -1.0, average: -0.86
# episode: 753/2000000, thread: 0, score: -1.0, average: -0.86
# episode: 754/2000000, thread: 0, score: -1.0, average: -0.86
# episode: 755/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 756/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 757/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 758/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 759/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 760/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 761/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 762/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 763/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 764/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 765/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 766/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 767/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 768/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 769/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 770/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 771/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 772/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 773/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 774/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 775/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 776/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 777/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 778/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 779/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 780/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 781/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 782/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 783/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 784/2000000, thread: 0, score: -1.0, average: -0.96
# episode: 785/2000000, thread: 0, score: -1.0, average: -0.96
# episode: 786/2000000, thread: 0, score: -1.0, average: -0.96
# episode: 787/2000000, thread: 0, score: -1.0, average: -1.00
# episode: 788/2000000, thread: 0, score: -1.0, average: -1.00
# episode: 789/2000000, thread: 0, score: -1.0, average: -1.00
# episode: 790/2000000, thread: 0, score: -1.0, average: -1.00
# episode: 791/2000000, thread: 0, score: -1.0, average: -1.00
# episode: 792/2000000, thread: 0, score: -1.0, average: -1.00
# episode: 793/2000000, thread: 0, score: -1.0, average: -1.00
# episode: 794/2000000, thread: 0, score: 0.0, average: -0.98
# episode: 795/2000000, thread: 0, score: -1.0, average: -0.98
# episode: 796/2000000, thread: 0, score: -1.0, average: -0.98
# episode: 797/2000000, thread: 0, score: -1.0, average: -0.98
# episode: 798/2000000, thread: 0, score: -1.0, average: -0.98
# episode: 799/2000000, thread: 0, score: -1.0, average: -0.98
# episode: 800/2000000, thread: 0, score: -1.0, average: -0.98
# episode: 801/2000000, thread: 0, score: -1.0, average: -0.98
# episode: 802/2000000, thread: 0, score: -1.0, average: -0.98
# episode: 803/2000000, thread: 0, score: -1.0, average: -0.98
# episode: 804/2000000, thread: 0, score: -1.0, average: -0.98
# episode: 805/2000000, thread: 0, score: -1.0, average: -0.98
# episode: 806/2000000, thread: 0, score: 0.0, average: -0.96
# episode: 807/2000000, thread: 0, score: -1.0, average: -0.96
# episode: 808/2000000, thread: 0, score: -1.0, average: -0.96
# episode: 809/2000000, thread: 0, score: -1.0, average: -0.96
# episode: 810/2000000, thread: 0, score: 0.0, average: -0.94
# episode: 811/2000000, thread: 0, score: 0.0, average: -0.92
# episode: 812/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 813/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 814/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 815/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 816/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 817/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 818/2000000, thread: 0, score: 0.0, average: -0.90
# episode: 819/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 820/2000000, thread: 0, score: 1.0, average: -0.86
# episode: 821/2000000, thread: 0, score: -1.0, average: -0.86
# episode: 822/2000000, thread: 0, score: -1.0, average: -0.86
# episode: 823/2000000, thread: 0, score: -1.0, average: -0.86
# episode: 824/2000000, thread: 0, score: -1.0, average: -0.86
# episode: 825/2000000, thread: 0, score: -1.0, average: -0.86
# episode: 826/2000000, thread: 0, score: -1.0, average: -0.86
# episode: 827/2000000, thread: 0, score: -1.0, average: -0.86
# episode: 828/2000000, thread: 0, score: -1.0, average: -0.86
# episode: 829/2000000, thread: 0, score: -1.0, average: -0.86
# episode: 830/2000000, thread: 0, score: -1.0, average: -0.86
# episode: 831/2000000, thread: 0, score: -1.0, average: -0.86
# episode: 832/2000000, thread: 0, score: -1.0, average: -0.86
# episode: 833/2000000, thread: 0, score: 0.0, average: -0.84
# episode: 834/2000000, thread: 0, score: -1.0, average: -0.84
# episode: 835/2000000, thread: 0, score: -1.0, average: -0.84
# episode: 836/2000000, thread: 0, score: -1.0, average: -0.84
# episode: 837/2000000, thread: 0, score: -1.0, average: -0.84
# episode: 838/2000000, thread: 0, score: -1.0, average: -0.84
# episode: 839/2000000, thread: 0, score: -1.0, average: -0.84
# episode: 840/2000000, thread: 0, score: -1.0, average: -0.84
# episode: 841/2000000, thread: 0, score: -1.0, average: -0.84
# episode: 842/2000000, thread: 0, score: -1.0, average: -0.84
# episode: 843/2000000, thread: 0, score: -1.0, average: -0.84
# episode: 844/2000000, thread: 0, score: -1.0, average: -0.86
# episode: 845/2000000, thread: 0, score: -1.0, average: -0.86
# episode: 846/2000000, thread: 0, score: -1.0, average: -0.86
# episode: 847/2000000, thread: 0, score: -1.0, average: -0.86
# episode: 848/2000000, thread: 0, score: 0.0, average: -0.84
# episode: 849/2000000, thread: 0, score: -1.0, average: -0.84
# episode: 850/2000000, thread: 0, score: -1.0, average: -0.84
# episode: 851/2000000, thread: 0, score: 0.0, average: -0.82
# episode: 852/2000000, thread: 0, score: -1.0, average: -0.82
# episode: 853/2000000, thread: 0, score: -1.0, average: -0.82
# episode: 854/2000000, thread: 0, score: -1.0, average: -0.82
# episode: 855/2000000, thread: 0, score: -1.0, average: -0.82
# episode: 856/2000000, thread: 0, score: -1.0, average: -0.84
# episode: 857/2000000, thread: 0, score: -1.0, average: -0.84
# episode: 858/2000000, thread: 0, score: -1.0, average: -0.84
# episode: 859/2000000, thread: 0, score: 0.0, average: -0.82
# episode: 860/2000000, thread: 0, score: -1.0, average: -0.84
# episode: 861/2000000, thread: 0, score: -1.0, average: -0.86
# episode: 862/2000000, thread: 0, score: -1.0, average: -0.86
# episode: 863/2000000, thread: 0, score: -1.0, average: -0.86
# episode: 864/2000000, thread: 0, score: -1.0, average: -0.86
# episode: 865/2000000, thread: 0, score: -1.0, average: -0.86
# episode: 866/2000000, thread: 0, score: -1.0, average: -0.86
# episode: 867/2000000, thread: 0, score: -1.0, average: -0.86
# episode: 868/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 869/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 870/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 871/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 872/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 873/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 874/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 875/2000000, thread: 0, score: 0.0, average: -0.90
# episode: 876/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 877/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 878/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 879/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 880/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 881/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 882/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 883/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 884/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 885/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 886/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 887/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 888/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 889/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 890/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 891/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 892/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 893/2000000, thread: 0, score: -1.0, average: -0.92
# episode: 894/2000000, thread: 0, score: 0.0, average: -0.90
# episode: 895/2000000, thread: 0, score: -1.0, average: -0.90
# episode: 896/2000000, thread: 0, score: 0.0, average: -0.88
# episode: 897/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 898/2000000, thread: 0, score: 0.0, average: -0.88
# episode: 899/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 900/2000000, thread: 0, score: -1.0, average: -0.88
# episode: 901/2000000, thread: 0, score: -1.0, average: -0.90
