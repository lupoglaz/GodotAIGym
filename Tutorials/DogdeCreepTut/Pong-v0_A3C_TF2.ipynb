# %%
import os
import random
import gym
import pylab
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Input, Dense, Lambda, Add, Conv2D, Flatten
from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras import backend as K
import cv2
import threading
from threading import Thread, Lock
import time
import tensorflow_probability as tfp
from typing import Any, List, Sequence, Tuple

os.environ['CUDA_VISIBLE_DEVICES'] = '-1'

tfd = tfp.distributions


class OurModel(tf.keras.Model):
    def __init__(self, input_shape, action_space):
        super(OurModel, self).__init__()
        
        self.flatten = Flatten()
        self.dense_0 = Dense(512, activation='relu')
        self.dense_1 = Dense(action_space)
        self.dense_2 = Dense(1)
        
    def call(self, X_input):
        X_input = self.flatten(X_input)
        X_input = self.dense_0(X_input)
        action_logit = self.dense_1(X_input)
        value = self.dense_2(X_input)
        
        return action_logit, value


def safe_log(x):
  """Computes a safe logarithm which returns 0 if x is zero."""
  return tf.where(
      tf.math.equal(x, 0),
      tf.zeros_like(x),
      tf.math.log(tf.math.maximum(1e-12, x)))


def take_vector_elements(vectors, indices):
    """
    For a batch of vectors, take a single vector component
    out of each vector.
    Args:
      vectors: a [batch x dims] Tensor.
      indices: an int32 Tensor with `batch` entries.
    Returns:
      A Tensor with `batch` entries, one for each vector.
    """
    return tf.gather_nd(vectors, tf.stack([tf.range(tf.shape(vectors)[0]), indices], axis=1))


huber_loss = tf.keras.losses.Huber(reduction=tf.keras.losses.Reduction.SUM)
sparse_ce = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True, reduction=tf.keras.losses.Reduction.SUM)
mse_loss = tf.keras.losses.MeanSquaredError()


class A3CAgent:
    # Actor-Critic Main Optimization Algorithm
    def __init__(self, env_name):
        # Initialization
        self.env_name = env_name       
        self.env = gym.make(env_name)
        self.action_size = self.env.action_space.n
        self.EPISODES, self.episode, self.max_average = 2000000, 0, -21.0 # specific for pong
        self.lock = Lock()
        self.lr = 0.0001

        self.ROWS = 80
        self.COLS = 80
        self.REM_STEP = 4

        # Instantiate plot memory
        self.scores, self.episodes, self.average = [], [], []

        self.Save_Path = 'Models'
        self.state_size = (self.REM_STEP, self.ROWS, self.COLS)
        
        if not os.path.exists(self.Save_Path): os.makedirs(self.Save_Path)
        self.path = '{}_A3C_{}'.format(self.env_name, self.lr)
        self.model_name = os.path.join(self.Save_Path, self.path)

        # Create Actor-Critic network model
        self.ActorCritic = OurModel(input_shape=self.state_size, action_space=self.action_size)
        
        self.optimizer = tf.keras.optimizers.Adam(self.lr)

    def act(self, state):
        # Use the network to predict the next action to take, using the model
        prediction = self.ActorCritic(state, training=False)
        action = tf.random.categorical(prediction[0], 1).numpy()

        return action[0][0]

    def discount_rewards(self, reward, dones):
        # Compute the gamma-discounted rewards over an episode
        gamma = 0.99    # discount rate
        running_add = 0
        discounted_r = np.zeros_like(reward)
        for i in reversed(range(0, len(reward))):
            if reward[i] != 0: # reset the sum, since this was a game boundary (pong specific!)
                running_add = 0

            running_add = running_add * gamma + reward[i]
            discounted_r[i] = running_add

        discounted_r -= np.mean(discounted_r) # normalizing the result
        discounted_r /= np.std(discounted_r) # divide by standard deviation

        return discounted_r
        
    def replay(self, states, actions, rewards, dones):
        # reshape memory to appropriate shape for training
        states = np.vstack(states)
        
        # Compute discounted rewards
        discounted_r = self.discount_rewards(rewards, dones)
        discounted_r_ = np.vstack(discounted_r)
        with tf.GradientTape() as tape:
            prediction = self.ActorCritic(states, training=True)
            action_logits = prediction[0]
            values = prediction[1]
            
            action_logits_selected = take_vector_elements(action_logits, actions)
            
            advantages = discounted_r - np.stack(values)[:, 0] 
            
            action_logits_selected = tf.nn.softmax(action_logits_selected)
            action_logits_selected_probs = tf.math.log(action_logits_selected)
            
            action_logits_ = tf.nn.softmax(action_logits)
            dist = tfd.Categorical(probs=action_logits_)
            action_log_prob = dist.prob(actions)
            action_log_prob = tf.math.log(action_log_prob)
            
            actor_loss = -tf.math.reduce_mean(action_logits_selected_probs * advantages) 
            
            action_probs = tf.nn.softmax(action_logits)
            
            critic_loss_ = huber_loss(values, discounted_r)
            critic_loss = mse_loss(values, discounted_r_)
            critic_loss = tf.cast(critic_loss, 'float32')
            
            total_loss = actor_loss + critic_loss
        
        #print("total_loss: ", total_loss)
        #print("")
            
        grads = tape.gradient(total_loss, self.ActorCritic.trainable_variables)
        self.optimizer.apply_gradients(zip(grads, self.ActorCritic.trainable_variables))
        
    def load(self, model_name):
        self.ActorCritic = load_model(model_name, compile=False)

    def save(self):
        self.ActorCritic.save(self.model_name)

    pylab.figure(figsize=(18, 9))
    def PlotModel(self, score, episode):
        self.scores.append(score)
        self.episodes.append(episode)
        self.average.append(sum(self.scores[-50:]) / len(self.scores[-50:]))
        if str(episode)[-2:] == "00":# much faster than episode % 100
            pylab.plot(self.episodes, self.scores, 'b')
            pylab.plot(self.episodes, self.average, 'r')
            pylab.ylabel('Score', fontsize=18)
            pylab.xlabel('Steps', fontsize=18)
            try:
                pylab.savefig(self.path + ".png")
            except OSError:
                pass

        return self.average[-1]
    
    def imshow(self, image, rem_step=0):
        cv2.imshow(self.model_name + str(rem_step), image[rem_step,...])
        if cv2.waitKey(25) & 0xFF == ord("q"):
            cv2.destroyAllWindows()
            return

    def GetImage(self, frame, image_memory):
        if image_memory.shape == (1,*self.state_size):
            image_memory = np.squeeze(image_memory)
            
        # croping frame to 80x80 size
        frame_cropped = frame[35:195:2, ::2,:]
        if frame_cropped.shape[0] != self.COLS or frame_cropped.shape[1] != self.ROWS:
            # OpenCV resize function 
            frame_cropped = cv2.resize(frame, (self.COLS, self.ROWS), interpolation=cv2.INTER_CUBIC)
        
        # converting to RGB (numpy way)
        frame_rgb = 0.299*frame_cropped[:,:,0] + 0.587*frame_cropped[:,:,1] + 0.114*frame_cropped[:,:,2]

        # convert everything to black and white (agent will train faster)
        frame_rgb[frame_rgb < 100] = 0
        frame_rgb[frame_rgb >= 100] = 255
        
        # dividing by 255 we expresses value to 0-1 representation
        new_frame = np.array(frame_rgb).astype(np.float32) / 255.0

        # push our data by 1 frame, similar as deq() function work
        image_memory = np.roll(image_memory, 1, axis = 0)

        # inserting new frame to free space
        image_memory[0,:,:] = new_frame

        return np.expand_dims(image_memory, axis=0)

    def reset(self, env):
        image_memory = np.zeros(self.state_size)
        frame = env.reset()
        
        for i in range(self.REM_STEP):
            state = self.GetImage(frame, image_memory)
            
        return state
    
    def step(self, action, env, image_memory):
        next_state, reward, done, info = env.step(action)
        next_state = self.GetImage(next_state, image_memory)
        
        return next_state, reward, done, info
    
    def train(self, n_threads):
        self.env.close()
        # Instantiate one environment per thread
        envs = [gym.make(self.env_name) for i in range(n_threads)]

        # Create threads
        threads = [threading.Thread(
                target=self.train_threading,
                daemon=True,
                args=(self,
                    envs[i],
                    i)) for i in range(n_threads)]

        for t in threads:
            time.sleep(2)
            t.start()
            
        for t in threads:
            time.sleep(10)
            t.join()
            
    def train_threading(self, agent, env, thread):
        while self.episode < self.EPISODES:
            # Reset episode
            score, done, SAVING = 0, False, ''
            state = self.reset(env)
            
            states, actions, rewards, dones = [], [], [], []
            while not done:
                action = agent.act(state)
                next_state, reward, done, _ = self.step(action, env, state)
                
                #print("next_state.shape: ", next_state.shape)
                #print("action: ", action)
                #print("reward: ", reward)
                #print("done: ", done)
                
                states.append(state)
                actions.append(action)
                rewards.append(reward)
                dones.append(done)

                score += reward
                state = next_state
                    
            self.lock.acquire()
            self.replay(states, actions, rewards, dones)
            self.lock.release()
            
            states, actions, rewards, dones = [], [], [], []
                    
            # Update episode count
            with self.lock:
                average = self.PlotModel(score, self.episode)
                # saving best models
                if average >= self.max_average:
                    self.max_average = average
                    #self.save()
                    SAVING = "SAVING"
                else:
                    SAVING = ""

                print("episode: {}/{}, thread: {}, score: {}, average: {:.2f} {}".format(self.episode, self.EPISODES, thread, score, average, SAVING))
                if(self.episode < self.EPISODES):
                    self.episode += 1

        env.close()            

    def test(self, Actor_name, Critic_name):
        self.load(Actor_name, Critic_name)
        for e in range(100):
            state = self.reset(self.env)
            done = False
            score = 0
            while not done:
                self.env.render()
                action = np.argmax(self.Actor.predict(state))
                state, reward, done, _ = self.step(action, self.env, state)
                score += reward
                if done:
                    print("episode: {}/{}, score: {}".format(e, self.EPISODES, score))
                    break

        self.env.close()


if __name__ == "__main__":
    env_name = 'PongDeterministic-v4'
    #env_name = 'Pong-v0'
    agent = A3CAgent(env_name)
    
    #agent.run() # use as A2C
    agent.train(n_threads=1) # use as A3C
    #agent.test('Models/Pong-v0_A3C_2.5e-05_Actor.h5', '')
# Out:
# 2022-08-14 14:03:50.074271: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2022-08-14 14:03:51.387134: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-08-14 14:03:51.387858: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2022-08-14 14:03:51.409624: E tensorflow/stream_executor/cuda/cuda_driver.cc:328] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-08-14 14:03:51.409643: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: kimbring2-ROG-Strix-GA35DX-G35DX
# 2022-08-14 14:03:51.409648: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: kimbring2-ROG-Strix-GA35DX-G35DX
# 2022-08-14 14:03:51.409717: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 470.42.1
# 2022-08-14 14:03:51.409731: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 470.42.1
# 2022-08-14 14:03:51.409735: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:310] kernel version seems to match DSO: 470.42.1
# 2022-08-14 14:03:51.409995: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-08-14 14:03:51.410469: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# episode: 0/2000000, thread: 0, score: -21.0, average: -21.00 SAVING
# episode: 1/2000000, thread: 0, score: -21.0, average: -21.00 SAVING
# episode: 2/2000000, thread: 0, score: -21.0, average: -21.00 SAVING
# episode: 3/2000000, thread: 0, score: -21.0, average: -21.00 SAVING
# episode: 4/2000000, thread: 0, score: -19.0, average: -20.60 SAVING
# episode: 5/2000000, thread: 0, score: -19.0, average: -20.33 SAVING
# episode: 6/2000000, thread: 0, score: -20.0, average: -20.29 SAVING
# episode: 7/2000000, thread: 0, score: -20.0, average: -20.25 SAVING
# episode: 8/2000000, thread: 0, score: -21.0, average: -20.33
# episode: 9/2000000, thread: 0, score: -20.0, average: -20.30
# episode: 10/2000000, thread: 0, score: -19.0, average: -20.18 SAVING
# episode: 11/2000000, thread: 0, score: -20.0, average: -20.17 SAVING
# episode: 12/2000000, thread: 0, score: -21.0, average: -20.23
# episode: 13/2000000, thread: 0, score: -21.0, average: -20.29
# episode: 14/2000000, thread: 0, score: -20.0, average: -20.27
# episode: 15/2000000, thread: 0, score: -21.0, average: -20.31
# episode: 16/2000000, thread: 0, score: -21.0, average: -20.35
# episode: 17/2000000, thread: 0, score: -19.0, average: -20.28
# episode: 18/2000000, thread: 0, score: -21.0, average: -20.32
# episode: 19/2000000, thread: 0, score: -19.0, average: -20.25
# episode: 20/2000000, thread: 0, score: -21.0, average: -20.29
# episode: 21/2000000, thread: 0, score: -20.0, average: -20.27
# episode: 22/2000000, thread: 0, score: -21.0, average: -20.30
# episode: 23/2000000, thread: 0, score: -20.0, average: -20.29
# episode: 24/2000000, thread: 0, score: -21.0, average: -20.32
# episode: 25/2000000, thread: 0, score: -21.0, average: -20.35
# episode: 26/2000000, thread: 0, score: -20.0, average: -20.33
# episode: 27/2000000, thread: 0, score: -21.0, average: -20.36
# episode: 28/2000000, thread: 0, score: -21.0, average: -20.38
# episode: 29/2000000, thread: 0, score: -19.0, average: -20.33
# episode: 30/2000000, thread: 0, score: -20.0, average: -20.32
# episode: 31/2000000, thread: 0, score: -21.0, average: -20.34
# episode: 32/2000000, thread: 0, score: -19.0, average: -20.30
# episode: 33/2000000, thread: 0, score: -21.0, average: -20.32
# episode: 34/2000000, thread: 0, score: -21.0, average: -20.34
# episode: 35/2000000, thread: 0, score: -20.0, average: -20.33
# episode: 36/2000000, thread: 0, score: -20.0, average: -20.32
# episode: 37/2000000, thread: 0, score: -20.0, average: -20.32
# episode: 38/2000000, thread: 0, score: -20.0, average: -20.31
# episode: 39/2000000, thread: 0, score: -21.0, average: -20.32
# episode: 40/2000000, thread: 0, score: -20.0, average: -20.32
# episode: 41/2000000, thread: 0, score: -20.0, average: -20.31
# episode: 42/2000000, thread: 0, score: -20.0, average: -20.30
# episode: 43/2000000, thread: 0, score: -21.0, average: -20.32
# episode: 44/2000000, thread: 0, score: -21.0, average: -20.33
# episode: 45/2000000, thread: 0, score: -20.0, average: -20.33
# episode: 46/2000000, thread: 0, score: -21.0, average: -20.34
# episode: 47/2000000, thread: 0, score: -21.0, average: -20.35
# episode: 48/2000000, thread: 0, score: -20.0, average: -20.35
# episode: 49/2000000, thread: 0, score: -20.0, average: -20.34
# episode: 50/2000000, thread: 0, score: -20.0, average: -20.32
# episode: 51/2000000, thread: 0, score: -20.0, average: -20.30
# episode: 52/2000000, thread: 0, score: -21.0, average: -20.30
# episode: 53/2000000, thread: 0, score: -20.0, average: -20.28
# episode: 54/2000000, thread: 0, score: -19.0, average: -20.28
# episode: 55/2000000, thread: 0, score: -20.0, average: -20.30
# episode: 56/2000000, thread: 0, score: -20.0, average: -20.30
# episode: 57/2000000, thread: 0, score: -20.0, average: -20.30
# episode: 58/2000000, thread: 0, score: -19.0, average: -20.26
# episode: 59/2000000, thread: 0, score: -21.0, average: -20.28
# episode: 60/2000000, thread: 0, score: -21.0, average: -20.32
# episode: 61/2000000, thread: 0, score: -21.0, average: -20.34
# episode: 62/2000000, thread: 0, score: -19.0, average: -20.30
# episode: 63/2000000, thread: 0, score: -21.0, average: -20.30
# episode: 64/2000000, thread: 0, score: -20.0, average: -20.30
# episode: 65/2000000, thread: 0, score: -20.0, average: -20.28
# episode: 66/2000000, thread: 0, score: -21.0, average: -20.28
# episode: 67/2000000, thread: 0, score: -21.0, average: -20.32
# episode: 68/2000000, thread: 0, score: -20.0, average: -20.30
# episode: 69/2000000, thread: 0, score: -21.0, average: -20.34
# episode: 70/2000000, thread: 0, score: -20.0, average: -20.32
# episode: 71/2000000, thread: 0, score: -20.0, average: -20.32
# episode: 72/2000000, thread: 0, score: -21.0, average: -20.32
# episode: 73/2000000, thread: 0, score: -21.0, average: -20.34
# episode: 74/2000000, thread: 0, score: -21.0, average: -20.34
# episode: 75/2000000, thread: 0, score: -19.0, average: -20.30
# episode: 76/2000000, thread: 0, score: -21.0, average: -20.32
# episode: 77/2000000, thread: 0, score: -20.0, average: -20.30
# episode: 78/2000000, thread: 0, score: -20.0, average: -20.28
# episode: 79/2000000, thread: 0, score: -21.0, average: -20.32
# episode: 80/2000000, thread: 0, score: -20.0, average: -20.32
# episode: 81/2000000, thread: 0, score: -20.0, average: -20.30
# episode: 82/2000000, thread: 0, score: -20.0, average: -20.32
# episode: 83/2000000, thread: 0, score: -20.0, average: -20.30
# episode: 84/2000000, thread: 0, score: -21.0, average: -20.30
# episode: 85/2000000, thread: 0, score: -19.0, average: -20.28
# episode: 86/2000000, thread: 0, score: -21.0, average: -20.30
# episode: 87/2000000, thread: 0, score: -20.0, average: -20.30
# episode: 88/2000000, thread: 0, score: -19.0, average: -20.28
# episode: 89/2000000, thread: 0, score: -21.0, average: -20.28
# episode: 90/2000000, thread: 0, score: -21.0, average: -20.30
# episode: 91/2000000, thread: 0, score: -21.0, average: -20.32
# episode: 92/2000000, thread: 0, score: -19.0, average: -20.30
# episode: 93/2000000, thread: 0, score: -20.0, average: -20.28
# episode: 94/2000000, thread: 0, score: -18.0, average: -20.22
# episode: 95/2000000, thread: 0, score: -21.0, average: -20.24
# episode: 96/2000000, thread: 0, score: -19.0, average: -20.20
# episode: 97/2000000, thread: 0, score: -21.0, average: -20.20
# episode: 98/2000000, thread: 0, score: -20.0, average: -20.20
# episode: 99/2000000, thread: 0, score: -20.0, average: -20.20
# episode: 100/2000000, thread: 0, score: -19.0, average: -20.18
# episode: 101/2000000, thread: 0, score: -21.0, average: -20.20
# episode: 102/2000000, thread: 0, score: -18.0, average: -20.14 SAVING
# episode: 103/2000000, thread: 0, score: -21.0, average: -20.16
# episode: 104/2000000, thread: 0, score: -18.0, average: -20.14 SAVING
# episode: 105/2000000, thread: 0, score: -20.0, average: -20.14 SAVING
# episode: 106/2000000, thread: 0, score: -21.0, average: -20.16
# episode: 107/2000000, thread: 0, score: -19.0, average: -20.14 SAVING
# episode: 108/2000000, thread: 0, score: -21.0, average: -20.18
# episode: 109/2000000, thread: 0, score: -21.0, average: -20.18
# episode: 110/2000000, thread: 0, score: -21.0, average: -20.18
# episode: 111/2000000, thread: 0, score: -20.0, average: -20.16
# episode: 112/2000000, thread: 0, score: -20.0, average: -20.18
# episode: 113/2000000, thread: 0, score: -20.0, average: -20.16
# episode: 114/2000000, thread: 0, score: -20.0, average: -20.16
# episode: 115/2000000, thread: 0, score: -21.0, average: -20.18
# episode: 116/2000000, thread: 0, score: -19.0, average: -20.14 SAVING
# episode: 117/2000000, thread: 0, score: -20.0, average: -20.12 SAVING
# episode: 118/2000000, thread: 0, score: -21.0, average: -20.14
# episode: 119/2000000, thread: 0, score: -21.0, average: -20.14
# episode: 120/2000000, thread: 0, score: -21.0, average: -20.16
# episode: 121/2000000, thread: 0, score: -21.0, average: -20.18
# episode: 122/2000000, thread: 0, score: -20.0, average: -20.16
# episode: 123/2000000, thread: 0, score: -20.0, average: -20.14
# episode: 124/2000000, thread: 0, score: -21.0, average: -20.14
# episode: 125/2000000, thread: 0, score: -18.0, average: -20.12 SAVING
# episode: 126/2000000, thread: 0, score: -20.0, average: -20.10 SAVING
# episode: 127/2000000, thread: 0, score: -19.0, average: -20.08 SAVING
# episode: 128/2000000, thread: 0, score: -19.0, average: -20.06 SAVING
# episode: 129/2000000, thread: 0, score: -20.0, average: -20.04 SAVING
# episode: 130/2000000, thread: 0, score: -20.0, average: -20.04 SAVING
# episode: 131/2000000, thread: 0, score: -21.0, average: -20.06
# episode: 132/2000000, thread: 0, score: -19.0, average: -20.04 SAVING
# episode: 133/2000000, thread: 0, score: -20.0, average: -20.04 SAVING
# episode: 134/2000000, thread: 0, score: -21.0, average: -20.04 SAVING
# episode: 135/2000000, thread: 0, score: -18.0, average: -20.02 SAVING
# episode: 136/2000000, thread: 0, score: -20.0, average: -20.00 SAVING
# episode: 137/2000000, thread: 0, score: -20.0, average: -20.00 SAVING
# episode: 138/2000000, thread: 0, score: -21.0, average: -20.04
# episode: 139/2000000, thread: 0, score: -20.0, average: -20.02
# episode: 140/2000000, thread: 0, score: -20.0, average: -20.00 SAVING
# episode: 141/2000000, thread: 0, score: -20.0, average: -19.98 SAVING
# episode: 142/2000000, thread: 0, score: -20.0, average: -20.00
# episode: 143/2000000, thread: 0, score: -20.0, average: -20.00
# episode: 144/2000000, thread: 0, score: -21.0, average: -20.06
# episode: 145/2000000, thread: 0, score: -20.0, average: -20.04
# episode: 146/2000000, thread: 0, score: -20.0, average: -20.06
# episode: 147/2000000, thread: 0, score: -19.0, average: -20.02
# episode: 148/2000000, thread: 0, score: -20.0, average: -20.02
# episode: 149/2000000, thread: 0, score: -19.0, average: -20.00
# episode: 150/2000000, thread: 0, score: -20.0, average: -20.02
# episode: 151/2000000, thread: 0, score: -21.0, average: -20.02
# episode: 152/2000000, thread: 0, score: -19.0, average: -20.04
# episode: 153/2000000, thread: 0, score: -21.0, average: -20.04
# episode: 154/2000000, thread: 0, score: -18.0, average: -20.04
# episode: 155/2000000, thread: 0, score: -20.0, average: -20.04
# episode: 156/2000000, thread: 0, score: -21.0, average: -20.04
# episode: 157/2000000, thread: 0, score: -20.0, average: -20.06
# episode: 158/2000000, thread: 0, score: -21.0, average: -20.06
# episode: 159/2000000, thread: 0, score: -21.0, average: -20.06
# episode: 160/2000000, thread: 0, score: -18.0, average: -20.00
# episode: 161/2000000, thread: 0, score: -19.0, average: -19.98 SAVING
# episode: 162/2000000, thread: 0, score: -20.0, average: -19.98 SAVING
# episode: 163/2000000, thread: 0, score: -20.0, average: -19.98 SAVING
# episode: 164/2000000, thread: 0, score: -19.0, average: -19.96 SAVING
# episode: 165/2000000, thread: 0, score: -18.0, average: -19.90 SAVING
# episode: 166/2000000, thread: 0, score: -19.0, average: -19.90 SAVING
# episode: 167/2000000, thread: 0, score: -21.0, average: -19.92
# episode: 168/2000000, thread: 0, score: -20.0, average: -19.90 SAVING
# episode: 169/2000000, thread: 0, score: -21.0, average: -19.90 SAVING
# episode: 170/2000000, thread: 0, score: -18.0, average: -19.84 SAVING
# episode: 171/2000000, thread: 0, score: -21.0, average: -19.84 SAVING
# episode: 172/2000000, thread: 0, score: -20.0, average: -19.84 SAVING
# episode: 173/2000000, thread: 0, score: -20.0, average: -19.84 SAVING
# episode: 174/2000000, thread: 0, score: -21.0, average: -19.84 SAVING
# episode: 175/2000000, thread: 0, score: -20.0, average: -19.88
# episode: 176/2000000, thread: 0, score: -19.0, average: -19.86
# episode: 177/2000000, thread: 0, score: -18.0, average: -19.84 SAVING
# episode: 178/2000000, thread: 0, score: -21.0, average: -19.88
# episode: 179/2000000, thread: 0, score: -20.0, average: -19.88
# episode: 180/2000000, thread: 0, score: -18.0, average: -19.84 SAVING
# episode: 181/2000000, thread: 0, score: -19.0, average: -19.80 SAVING
# episode: 182/2000000, thread: 0, score: -21.0, average: -19.84
# episode: 183/2000000, thread: 0, score: -21.0, average: -19.86
# episode: 184/2000000, thread: 0, score: -19.0, average: -19.82
# episode: 185/2000000, thread: 0, score: -18.0, average: -19.82
# episode: 186/2000000, thread: 0, score: -19.0, average: -19.80 SAVING
# episode: 187/2000000, thread: 0, score: -16.0, average: -19.72 SAVING
# episode: 188/2000000, thread: 0, score: -21.0, average: -19.72 SAVING
# episode: 189/2000000, thread: 0, score: -20.0, average: -19.72 SAVING
# episode: 190/2000000, thread: 0, score: -21.0, average: -19.74
# episode: 191/2000000, thread: 0, score: -21.0, average: -19.76
# episode: 192/2000000, thread: 0, score: -19.0, average: -19.74
# episode: 193/2000000, thread: 0, score: -19.0, average: -19.72 SAVING
# episode: 194/2000000, thread: 0, score: -19.0, average: -19.68 SAVING
# episode: 195/2000000, thread: 0, score: -19.0, average: -19.66 SAVING
# episode: 196/2000000, thread: 0, score: -21.0, average: -19.68
# episode: 197/2000000, thread: 0, score: -20.0, average: -19.70
# episode: 198/2000000, thread: 0, score: -18.0, average: -19.66 SAVING
# episode: 199/2000000, thread: 0, score: -20.0, average: -19.68
# episode: 200/2000000, thread: 0, score: -20.0, average: -19.68
# episode: 201/2000000, thread: 0, score: -21.0, average: -19.68
# episode: 202/2000000, thread: 0, score: -19.0, average: -19.68
# episode: 203/2000000, thread: 0, score: -19.0, average: -19.64 SAVING
# episode: 204/2000000, thread: 0, score: -17.0, average: -19.62 SAVING
# episode: 205/2000000, thread: 0, score: -18.0, average: -19.58 SAVING
# episode: 206/2000000, thread: 0, score: -21.0, average: -19.58 SAVING
# episode: 207/2000000, thread: 0, score: -18.0, average: -19.54 SAVING
# episode: 208/2000000, thread: 0, score: -18.0, average: -19.48 SAVING
# episode: 209/2000000, thread: 0, score: -19.0, average: -19.44 SAVING
# episode: 210/2000000, thread: 0, score: -18.0, average: -19.44 SAVING
# episode: 211/2000000, thread: 0, score: -16.0, average: -19.38 SAVING
# episode: 212/2000000, thread: 0, score: -20.0, average: -19.38 SAVING
# episode: 213/2000000, thread: 0, score: -20.0, average: -19.38 SAVING
# episode: 214/2000000, thread: 0, score: -20.0, average: -19.40
# episode: 215/2000000, thread: 0, score: -19.0, average: -19.42
# episode: 216/2000000, thread: 0, score: -21.0, average: -19.46
# episode: 217/2000000, thread: 0, score: -19.0, average: -19.42
# episode: 218/2000000, thread: 0, score: -20.0, average: -19.42
# episode: 219/2000000, thread: 0, score: -20.0, average: -19.40
# episode: 220/2000000, thread: 0, score: -19.0, average: -19.42
# episode: 221/2000000, thread: 0, score: -20.0, average: -19.40
# episode: 222/2000000, thread: 0, score: -20.0, average: -19.40
# episode: 223/2000000, thread: 0, score: -17.0, average: -19.34 SAVING
# episode: 224/2000000, thread: 0, score: -20.0, average: -19.32 SAVING
# episode: 225/2000000, thread: 0, score: -18.0, average: -19.28 SAVING
# episode: 226/2000000, thread: 0, score: -18.0, average: -19.26 SAVING
# episode: 227/2000000, thread: 0, score: -20.0, average: -19.30
# episode: 228/2000000, thread: 0, score: -18.0, average: -19.24 SAVING
# episode: 229/2000000, thread: 0, score: -20.0, average: -19.24 SAVING
# episode: 230/2000000, thread: 0, score: -20.0, average: -19.28
# episode: 231/2000000, thread: 0, score: -19.0, average: -19.28
# episode: 232/2000000, thread: 0, score: -19.0, average: -19.24 SAVING
# episode: 233/2000000, thread: 0, score: -21.0, average: -19.24 SAVING
# episode: 234/2000000, thread: 0, score: -18.0, average: -19.22 SAVING
# episode: 235/2000000, thread: 0, score: -17.0, average: -19.20 SAVING
# episode: 236/2000000, thread: 0, score: -21.0, average: -19.24
# episode: 237/2000000, thread: 0, score: -20.0, average: -19.32
# episode: 238/2000000, thread: 0, score: -21.0, average: -19.32
# episode: 239/2000000, thread: 0, score: -19.0, average: -19.30
# episode: 240/2000000, thread: 0, score: -19.0, average: -19.26
# episode: 241/2000000, thread: 0, score: -20.0, average: -19.24
# episode: 242/2000000, thread: 0, score: -19.0, average: -19.24
# episode: 243/2000000, thread: 0, score: -20.0, average: -19.26
# episode: 244/2000000, thread: 0, score: -18.0, average: -19.24
# episode: 245/2000000, thread: 0, score: -20.0, average: -19.26
# episode: 246/2000000, thread: 0, score: -21.0, average: -19.26
# episode: 247/2000000, thread: 0, score: -19.0, average: -19.24
# episode: 248/2000000, thread: 0, score: -19.0, average: -19.26
# episode: 249/2000000, thread: 0, score: -21.0, average: -19.28
# episode: 250/2000000, thread: 0, score: -21.0, average: -19.30
# episode: 251/2000000, thread: 0, score: -18.0, average: -19.24
# episode: 252/2000000, thread: 0, score: -19.0, average: -19.24
# episode: 253/2000000, thread: 0, score: -21.0, average: -19.28
# episode: 254/2000000, thread: 0, score: -16.0, average: -19.26
# episode: 255/2000000, thread: 0, score: -17.0, average: -19.24
# episode: 256/2000000, thread: 0, score: -18.0, average: -19.18 SAVING
# episode: 257/2000000, thread: 0, score: -20.0, average: -19.22
# episode: 258/2000000, thread: 0, score: -19.0, average: -19.24
# episode: 259/2000000, thread: 0, score: -21.0, average: -19.28
# episode: 260/2000000, thread: 0, score: -18.0, average: -19.28
# episode: 261/2000000, thread: 0, score: -20.0, average: -19.36
# episode: 262/2000000, thread: 0, score: -21.0, average: -19.38
# episode: 263/2000000, thread: 0, score: -18.0, average: -19.34
# episode: 264/2000000, thread: 0, score: -20.0, average: -19.34
# episode: 265/2000000, thread: 0, score: -17.0, average: -19.30
# episode: 266/2000000, thread: 0, score: -17.0, average: -19.22
# episode: 267/2000000, thread: 0, score: -18.0, average: -19.20
# episode: 268/2000000, thread: 0, score: -17.0, average: -19.14 SAVING
# episode: 269/2000000, thread: 0, score: -21.0, average: -19.16
# episode: 270/2000000, thread: 0, score: -19.0, average: -19.16
# episode: 271/2000000, thread: 0, score: -19.0, average: -19.14 SAVING
# episode: 272/2000000, thread: 0, score: -16.0, average: -19.06 SAVING
# episode: 273/2000000, thread: 0, score: -17.0, average: -19.06 SAVING
# episode: 274/2000000, thread: 0, score: -21.0, average: -19.08
# episode: 275/2000000, thread: 0, score: -20.0, average: -19.12
# episode: 276/2000000, thread: 0, score: -20.0, average: -19.16
# episode: 277/2000000, thread: 0, score: -20.0, average: -19.16
# episode: 278/2000000, thread: 0, score: -18.0, average: -19.16
# episode: 279/2000000, thread: 0, score: -20.0, average: -19.16
# episode: 280/2000000, thread: 0, score: -18.0, average: -19.12
# episode: 281/2000000, thread: 0, score: -19.0, average: -19.12
# episode: 282/2000000, thread: 0, score: -15.0, average: -19.04 SAVING
# episode: 283/2000000, thread: 0, score: -21.0, average: -19.04 SAVING
# episode: 284/2000000, thread: 0, score: -21.0, average: -19.10
# episode: 285/2000000, thread: 0, score: -20.0, average: -19.16
# episode: 286/2000000, thread: 0, score: -20.0, average: -19.14
# episode: 287/2000000, thread: 0, score: -21.0, average: -19.16
# episode: 288/2000000, thread: 0, score: -19.0, average: -19.12
# episode: 289/2000000, thread: 0, score: -20.0, average: -19.14
# episode: 290/2000000, thread: 0, score: -16.0, average: -19.08
# episode: 291/2000000, thread: 0, score: -18.0, average: -19.04 SAVING
# episode: 292/2000000, thread: 0, score: -17.0, average: -19.00 SAVING
# episode: 293/2000000, thread: 0, score: -19.0, average: -18.98 SAVING
# episode: 294/2000000, thread: 0, score: -18.0, average: -18.98 SAVING
# episode: 295/2000000, thread: 0, score: -16.0, average: -18.90 SAVING
# episode: 296/2000000, thread: 0, score: -17.0, average: -18.82 SAVING
# episode: 297/2000000, thread: 0, score: -19.0, average: -18.82 SAVING
# episode: 298/2000000, thread: 0, score: -20.0, average: -18.84
# episode: 299/2000000, thread: 0, score: -21.0, average: -18.84
# episode: 300/2000000, thread: 0, score: -15.0, average: -18.72 SAVING
# episode: 301/2000000, thread: 0, score: -21.0, average: -18.78
# episode: 302/2000000, thread: 0, score: -16.0, average: -18.72 SAVING
# episode: 303/2000000, thread: 0, score: -18.0, average: -18.66 SAVING
# episode: 304/2000000, thread: 0, score: -19.0, average: -18.72
# episode: 305/2000000, thread: 0, score: -19.0, average: -18.76
# episode: 306/2000000, thread: 0, score: -20.0, average: -18.80
# episode: 307/2000000, thread: 0, score: -19.0, average: -18.78
# episode: 308/2000000, thread: 0, score: -17.0, average: -18.74
# episode: 309/2000000, thread: 0, score: -18.0, average: -18.68
# episode: 310/2000000, thread: 0, score: -19.0, average: -18.70
# episode: 311/2000000, thread: 0, score: -20.0, average: -18.70
# episode: 312/2000000, thread: 0, score: -20.0, average: -18.68
# episode: 313/2000000, thread: 0, score: -20.0, average: -18.72
# episode: 314/2000000, thread: 0, score: -21.0, average: -18.74
# episode: 315/2000000, thread: 0, score: -19.0, average: -18.78
# episode: 316/2000000, thread: 0, score: -20.0, average: -18.84
# episode: 317/2000000, thread: 0, score: -18.0, average: -18.84
# episode: 318/2000000, thread: 0, score: -18.0, average: -18.86
# episode: 319/2000000, thread: 0, score: -20.0, average: -18.84
# episode: 320/2000000, thread: 0, score: -21.0, average: -18.88
# episode: 321/2000000, thread: 0, score: -18.0, average: -18.86
# episode: 322/2000000, thread: 0, score: -17.0, average: -18.88
# episode: 323/2000000, thread: 0, score: -20.0, average: -18.94
# episode: 324/2000000, thread: 0, score: -20.0, average: -18.92
# episode: 325/2000000, thread: 0, score: -16.0, average: -18.84
# episode: 326/2000000, thread: 0, score: -20.0, average: -18.84
# episode: 327/2000000, thread: 0, score: -17.0, average: -18.78
# episode: 328/2000000, thread: 0, score: -17.0, average: -18.76
# episode: 329/2000000, thread: 0, score: -17.0, average: -18.70
# episode: 330/2000000, thread: 0, score: -16.0, average: -18.66 SAVING
# episode: 331/2000000, thread: 0, score: -20.0, average: -18.68
# episode: 332/2000000, thread: 0, score: -18.0, average: -18.74
# episode: 333/2000000, thread: 0, score: -19.0, average: -18.70
# episode: 334/2000000, thread: 0, score: -20.0, average: -18.68
# episode: 335/2000000, thread: 0, score: -19.0, average: -18.66 SAVING
# episode: 336/2000000, thread: 0, score: -18.0, average: -18.62 SAVING
# episode: 337/2000000, thread: 0, score: -17.0, average: -18.54 SAVING
# episode: 338/2000000, thread: 0, score: -19.0, average: -18.54 SAVING
# episode: 339/2000000, thread: 0, score: -17.0, average: -18.48 SAVING
# episode: 340/2000000, thread: 0, score: -16.0, average: -18.48 SAVING
# episode: 341/2000000, thread: 0, score: -13.0, average: -18.38 SAVING
# episode: 342/2000000, thread: 0, score: -20.0, average: -18.44
# episode: 343/2000000, thread: 0, score: -20.0, average: -18.46
# episode: 344/2000000, thread: 0, score: -16.0, average: -18.42
# episode: 345/2000000, thread: 0, score: -19.0, average: -18.48
# episode: 346/2000000, thread: 0, score: -18.0, average: -18.50
# episode: 347/2000000, thread: 0, score: -17.0, average: -18.46
# episode: 348/2000000, thread: 0, score: -20.0, average: -18.46
# episode: 349/2000000, thread: 0, score: -20.0, average: -18.44
# episode: 350/2000000, thread: 0, score: -20.0, average: -18.54
# episode: 351/2000000, thread: 0, score: -20.0, average: -18.52
# episode: 352/2000000, thread: 0, score: -16.0, average: -18.52
# episode: 353/2000000, thread: 0, score: -20.0, average: -18.56
# episode: 354/2000000, thread: 0, score: -17.0, average: -18.52
# episode: 355/2000000, thread: 0, score: -20.0, average: -18.54
# episode: 356/2000000, thread: 0, score: -19.0, average: -18.52
# episode: 357/2000000, thread: 0, score: -16.0, average: -18.46
# episode: 358/2000000, thread: 0, score: -18.0, average: -18.48
# episode: 359/2000000, thread: 0, score: -18.0, average: -18.48
# episode: 360/2000000, thread: 0, score: -18.0, average: -18.46
# episode: 361/2000000, thread: 0, score: -18.0, average: -18.42
# episode: 362/2000000, thread: 0, score: -16.0, average: -18.34 SAVING
# episode: 363/2000000, thread: 0, score: -16.0, average: -18.26 SAVING
# episode: 364/2000000, thread: 0, score: -20.0, average: -18.24 SAVING
# episode: 365/2000000, thread: 0, score: -18.0, average: -18.22 SAVING
# episode: 366/2000000, thread: 0, score: -17.0, average: -18.16 SAVING
# episode: 367/2000000, thread: 0, score: -17.0, average: -18.14 SAVING
# episode: 368/2000000, thread: 0, score: -17.0, average: -18.12 SAVING
# episode: 369/2000000, thread: 0, score: -16.0, average: -18.04 SAVING
# episode: 370/2000000, thread: 0, score: -19.0, average: -18.00 SAVING
# episode: 371/2000000, thread: 0, score: -20.0, average: -18.04
# episode: 372/2000000, thread: 0, score: -17.0, average: -18.04
# episode: 373/2000000, thread: 0, score: -18.0, average: -18.00 SAVING
# episode: 374/2000000, thread: 0, score: -17.0, average: -17.94 SAVING
# episode: 375/2000000, thread: 0, score: -20.0, average: -18.02
# episode: 376/2000000, thread: 0, score: -19.0, average: -18.00
# episode: 377/2000000, thread: 0, score: -17.0, average: -18.00
# episode: 378/2000000, thread: 0, score: -16.0, average: -17.98
# episode: 379/2000000, thread: 0, score: -19.0, average: -18.02
# episode: 380/2000000, thread: 0, score: -18.0, average: -18.06
# episode: 381/2000000, thread: 0, score: -21.0, average: -18.08
# episode: 382/2000000, thread: 0, score: -20.0, average: -18.12
# episode: 383/2000000, thread: 0, score: -20.0, average: -18.14
# episode: 384/2000000, thread: 0, score: -17.0, average: -18.08
# episode: 385/2000000, thread: 0, score: -19.0, average: -18.08
# episode: 386/2000000, thread: 0, score: -18.0, average: -18.08
# episode: 387/2000000, thread: 0, score: -20.0, average: -18.14
# episode: 388/2000000, thread: 0, score: -18.0, average: -18.12
# episode: 389/2000000, thread: 0, score: -17.0, average: -18.12
# episode: 390/2000000, thread: 0, score: -19.0, average: -18.18
# episode: 391/2000000, thread: 0, score: -13.0, average: -18.18
# episode: 392/2000000, thread: 0, score: -19.0, average: -18.16
# episode: 393/2000000, thread: 0, score: -18.0, average: -18.12
# episode: 394/2000000, thread: 0, score: -18.0, average: -18.16
# episode: 395/2000000, thread: 0, score: -18.0, average: -18.14
# episode: 396/2000000, thread: 0, score: -17.0, average: -18.12
# episode: 397/2000000, thread: 0, score: -18.0, average: -18.14
# episode: 398/2000000, thread: 0, score: -19.0, average: -18.12
# episode: 399/2000000, thread: 0, score: -17.0, average: -18.06
# episode: 400/2000000, thread: 0, score: -18.0, average: -18.02
# episode: 401/2000000, thread: 0, score: -21.0, average: -18.04
# episode: 402/2000000, thread: 0, score: -17.0, average: -18.06
# episode: 403/2000000, thread: 0, score: -18.0, average: -18.02
# episode: 404/2000000, thread: 0, score: -16.0, average: -18.00
# episode: 405/2000000, thread: 0, score: -18.0, average: -17.96
# episode: 406/2000000, thread: 0, score: -18.0, average: -17.94 SAVING
# episode: 407/2000000, thread: 0, score: -16.0, average: -17.94 SAVING
# episode: 408/2000000, thread: 0, score: -17.0, average: -17.92 SAVING
# episode: 409/2000000, thread: 0, score: -14.0, average: -17.84 SAVING
# episode: 410/2000000, thread: 0, score: -17.0, average: -17.82 SAVING
# episode: 411/2000000, thread: 0, score: -17.0, average: -17.80 SAVING
# episode: 412/2000000, thread: 0, score: -19.0, average: -17.86
# episode: 413/2000000, thread: 0, score: -18.0, average: -17.90
# episode: 414/2000000, thread: 0, score: -18.0, average: -17.86
# episode: 415/2000000, thread: 0, score: -15.0, average: -17.80 SAVING
# episode: 416/2000000, thread: 0, score: -17.0, average: -17.80 SAVING
# episode: 417/2000000, thread: 0, score: -14.0, average: -17.74 SAVING
# episode: 418/2000000, thread: 0, score: -17.0, average: -17.74 SAVING
# episode: 419/2000000, thread: 0, score: -18.0, average: -17.78
# episode: 420/2000000, thread: 0, score: -19.0, average: -17.78
# episode: 421/2000000, thread: 0, score: -20.0, average: -17.78
# episode: 422/2000000, thread: 0, score: -19.0, average: -17.82
# episode: 423/2000000, thread: 0, score: -16.0, average: -17.78
# episode: 424/2000000, thread: 0, score: -20.0, average: -17.84
# episode: 425/2000000, thread: 0, score: -15.0, average: -17.74 SAVING
# episode: 426/2000000, thread: 0, score: -18.0, average: -17.72 SAVING
# episode: 427/2000000, thread: 0, score: -18.0, average: -17.74
# episode: 428/2000000, thread: 0, score: -20.0, average: -17.82
# episode: 429/2000000, thread: 0, score: -17.0, average: -17.78
# episode: 430/2000000, thread: 0, score: -17.0, average: -17.76
# episode: 431/2000000, thread: 0, score: -20.0, average: -17.74
# episode: 432/2000000, thread: 0, score: -15.0, average: -17.64 SAVING
# episode: 433/2000000, thread: 0, score: -18.0, average: -17.60 SAVING
# episode: 434/2000000, thread: 0, score: -17.0, average: -17.60 SAVING
# episode: 435/2000000, thread: 0, score: -18.0, average: -17.58 SAVING
# episode: 436/2000000, thread: 0, score: -19.0, average: -17.60
# episode: 437/2000000, thread: 0, score: -16.0, average: -17.52 SAVING
# episode: 438/2000000, thread: 0, score: -18.0, average: -17.52 SAVING
# episode: 439/2000000, thread: 0, score: -19.0, average: -17.56
# episode: 440/2000000, thread: 0, score: -16.0, average: -17.50 SAVING
# episode: 441/2000000, thread: 0, score: -19.0, average: -17.62
# episode: 442/2000000, thread: 0, score: -17.0, average: -17.58
# episode: 443/2000000, thread: 0, score: -17.0, average: -17.56
# episode: 444/2000000, thread: 0, score: -16.0, average: -17.52
# episode: 445/2000000, thread: 0, score: -12.0, average: -17.40 SAVING
# episode: 446/2000000, thread: 0, score: -15.0, average: -17.36 SAVING
# episode: 447/2000000, thread: 0, score: -18.0, average: -17.36 SAVING
# episode: 448/2000000, thread: 0, score: -20.0, average: -17.38
# episode: 449/2000000, thread: 0, score: -17.0, average: -17.38
# episode: 450/2000000, thread: 0, score: -19.0, average: -17.40
# episode: 451/2000000, thread: 0, score: -21.0, average: -17.40
# episode: 452/2000000, thread: 0, score: -17.0, average: -17.40
# episode: 453/2000000, thread: 0, score: -14.0, average: -17.32 SAVING
# episode: 454/2000000, thread: 0, score: -14.0, average: -17.28 SAVING
# episode: 455/2000000, thread: 0, score: -18.0, average: -17.28 SAVING
# episode: 456/2000000, thread: 0, score: -14.0, average: -17.20 SAVING
# episode: 457/2000000, thread: 0, score: -18.0, average: -17.24
# episode: 458/2000000, thread: 0, score: -17.0, average: -17.24
# episode: 459/2000000, thread: 0, score: -18.0, average: -17.32
# episode: 460/2000000, thread: 0, score: -19.0, average: -17.36
# episode: 461/2000000, thread: 0, score: -18.0, average: -17.38
# episode: 462/2000000, thread: 0, score: -14.0, average: -17.28
# episode: 463/2000000, thread: 0, score: -15.0, average: -17.22
# episode: 464/2000000, thread: 0, score: -17.0, average: -17.20 SAVING
# episode: 465/2000000, thread: 0, score: -15.0, average: -17.20 SAVING
# episode: 466/2000000, thread: 0, score: -17.0, average: -17.20 SAVING
# episode: 467/2000000, thread: 0, score: -15.0, average: -17.22
# episode: 468/2000000, thread: 0, score: -15.0, average: -17.18 SAVING
# episode: 469/2000000, thread: 0, score: -17.0, average: -17.16 SAVING
# episode: 470/2000000, thread: 0, score: -19.0, average: -17.16 SAVING
# episode: 471/2000000, thread: 0, score: -14.0, average: -17.04 SAVING
# episode: 472/2000000, thread: 0, score: -12.0, average: -16.90 SAVING
# episode: 473/2000000, thread: 0, score: -19.0, average: -16.96
# episode: 474/2000000, thread: 0, score: -18.0, average: -16.92
# episode: 475/2000000, thread: 0, score: -18.0, average: -16.98
# episode: 476/2000000, thread: 0, score: -19.0, average: -17.00
# episode: 477/2000000, thread: 0, score: -15.0, average: -16.94
# episode: 478/2000000, thread: 0, score: -16.0, average: -16.86 SAVING
# episode: 479/2000000, thread: 0, score: -18.0, average: -16.88
# episode: 480/2000000, thread: 0, score: -17.0, average: -16.88
# episode: 481/2000000, thread: 0, score: -19.0, average: -16.86 SAVING
# episode: 482/2000000, thread: 0, score: -18.0, average: -16.92
# episode: 483/2000000, thread: 0, score: -20.0, average: -16.96
# episode: 484/2000000, thread: 0, score: -18.0, average: -16.98
# episode: 485/2000000, thread: 0, score: -16.0, average: -16.94
# episode: 486/2000000, thread: 0, score: -15.0, average: -16.86 SAVING
# episode: 487/2000000, thread: 0, score: -15.0, average: -16.84 SAVING
# episode: 488/2000000, thread: 0, score: -16.0, average: -16.80 SAVING
# episode: 489/2000000, thread: 0, score: -17.0, average: -16.76 SAVING
# episode: 490/2000000, thread: 0, score: -19.0, average: -16.82
# episode: 491/2000000, thread: 0, score: -14.0, average: -16.72 SAVING
# episode: 492/2000000, thread: 0, score: -17.0, average: -16.72 SAVING
# episode: 493/2000000, thread: 0, score: -16.0, average: -16.70 SAVING
# episode: 494/2000000, thread: 0, score: -18.0, average: -16.74
# episode: 495/2000000, thread: 0, score: -19.0, average: -16.88
# episode: 496/2000000, thread: 0, score: -17.0, average: -16.92
# episode: 497/2000000, thread: 0, score: -18.0, average: -16.92
# episode: 498/2000000, thread: 0, score: -17.0, average: -16.86
# episode: 499/2000000, thread: 0, score: -14.0, average: -16.80
# episode: 500/2000000, thread: 0, score: -20.0, average: -16.82
# episode: 501/2000000, thread: 0, score: -17.0, average: -16.74
# episode: 502/2000000, thread: 0, score: -18.0, average: -16.76
# episode: 503/2000000, thread: 0, score: -19.0, average: -16.86
# episode: 504/2000000, thread: 0, score: -16.0, average: -16.90
# episode: 505/2000000, thread: 0, score: -13.0, average: -16.80
# episode: 506/2000000, thread: 0, score: -16.0, average: -16.84
# episode: 507/2000000, thread: 0, score: -14.0, average: -16.76
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_3144102/2665088921.py in <module>
#     328
#     329     #agent.run() # use as A2C
# --> 330     agent.train(n_threads=1) # use as A3C
#     331     #agent.test('Models/Pong-v0_A3C_2.5e-05_Actor.h5', '')
#
# /tmp/ipykernel_3144102/2665088921.py in train(self, n_threads)
#     255         for t in threads:
#     256             time.sleep(10)
# --> 257             t.join()
#     258
#     259     def train_threading(self, agent, env, thread):
#
# /usr/lib/python3.7/threading.py in join(self, timeout)
#    1042
#    1043         if timeout is None:
# -> 1044             self._wait_for_tstate_lock()
#    1045         else:
#    1046             # the behavior of a negative timeout isn't documented, but
#
# /usr/lib/python3.7/threading.py in _wait_for_tstate_lock(self, block, timeout)
#    1058         if lock is None:  # already determined that the C code is done
#    1059             assert self._is_stopped
# -> 1060         elif lock.acquire(block, timeout):
#    1061             lock.release()
#    1062             self._stop()
#
# KeyboardInterrupt:
